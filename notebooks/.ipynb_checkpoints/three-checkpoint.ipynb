# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc
from collections import Counter
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GroupKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, classification_report
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %%
class Config:
    TRAIN_PATH = '../inputs/train.csv'
    TEST_PATH = '../inputs/test.csv'
    TRAIN_LABELS = '../inputs/train_labels.csv'
    SAMPLE_SUBMISSION = '../inputs/sample_submission.csv'

# %%
train_df = pd.read_csv(Config.TRAIN_PATH, usecols=lambda x: x not in ['fullscreen','hq','music'])
train_labels = pd.read_csv(Config.TRAIN_LABELS)

# %%
train_df.rename(columns={'session_id':'session'},inplace=True)

# %%
train_labels['question'] = train_labels['session_id'].str.split('q').str[-1].astype('int')
train_labels['session'] = train_labels['session_id'].str.split('_').str[0].astype('int64')

# %%
def q2l(x):
    if x <= 3:
        return '0-4'
    if x <= 12:
        return '5-12'
    return '13-22'
train_labels['level_group'] = train_labels['question'].apply(lambda x: q2l(x))

# %%
event_features =  ['checkpoint_click','cutscene_click', 'person_click', 'navigate_click',
                   'observation_click', 'notification_click', 'object_click',
                   'object_hover', 'map_hover', 'map_click', 'notebook_click']
name_features = ['basic', 'undefined', 'close', 'open', 'prev', 'next']
def groupby_apply(g):
    res = {}
    event_name_dict = Counter(g['event_name'].values)
    event_sequence = g['event_name'].values[1:]
    for col in event_features:
        res[f'{col}_sum'] = event_name_dict.get(col, 0)
    elapsed_time_diff = np.diff(g['elapsed_time'])
    res['elapsed_time_diff_mean'] = np.mean(elapsed_time_diff)
    res['elapsed_time_diff_std'] = np.std(elapsed_time_diff)
    res['elapsed_time_diff_max'] = np.max(elapsed_time_diff)
    res['elapsed_time_diff_min'] = np.min(elapsed_time_diff)
    res['duration'] = g['elapsed_time'].values[-1] - g['elapsed_time'].values[0]
    res['elapsed_time_diff_positive'] = len(elapsed_time_diff[elapsed_time_diff>0])
    for col in event_features:
        elapsed_time_diff_event = elapsed_time_diff[event_sequence==col]
        if len(elapsed_time_diff_event) > 0 :
            res[f'elapsed_time_diff_{col}_mean'] = np.mean(elapsed_time_diff[event_sequence==col])
            res[f'elapsed_time_diff_{col}_max'] = np.max(elapsed_time_diff[event_sequence==col])
            res[f'elapsed_time_diff_{col}_min'] = np.min(elapsed_time_diff[event_sequence==col])
        else:
            res[f'elapsed_time_diff_{col}_mean'] = 0
            res[f'elapsed_time_diff_{col}_max'] = 0
            res[f'elapsed_time_diff_{col}_min'] = 0
    return pd.Series(res)

# %%
def feature_engineering(df, meta):
    X = df.groupby(['session','level_group']).apply(groupby_apply).reset_index()
    X = meta.merge(X,how='left', on=['session','level_group'])
    X['question'] = X['question'].astype('category')
    X['level_group'] = X['level_group'].astype('category')
    for i in range(1,19):
        X[f'q{i}'] = X['question'] == i
    for i in ['0-4','5-12','13-22']:
        X[i] =  X['level_group'] == i
    return X

# %%
# %%time
X = feature_engineering(train_df, train_labels)
# Out:
# CPU times: total: 24.5 s
# Wall time: 24.5 s

# %%
FEATURES = X.columns[5:]

# %%
n_splits=5
gkf = GroupKFold(n_splits=n_splits)
oof = np.zeros(X.shape[0])
models = {}

# COMPUTE CV SCORE WITH 5 GROUP K FOLD
for i, (train_index, valid_index) in enumerate(gkf.split(X, groups=X['session'])):
    print('#'*25)
    print('### Fold',i+1)
    print('#'*25)

    xgb_params = {
        'objective' : 'binary:logistic',
        'eval_metric':'logloss',
        'learning_rate': 0.01,
        'max_depth': 5,
        'n_estimators': 3000,
        'early_stopping_rounds': 50,
        'tree_method':'hist',
        'subsample':0.8,
        'colsample_bytree': 0.8,
        'tree_method': 'gpu_hist',
        'seed':42,
        'use_label_encoder' : False}

    X_train = X.iloc[train_index][FEATURES]
    X_valid = X.iloc[valid_index][FEATURES]
    y_train = X.iloc[train_index]['correct'].values
    y_valid = X.iloc[valid_index]['correct'].values
        # TRAIN MODEL
    clf =  XGBClassifier(**xgb_params)
    clf.fit(X_train.astype('float32'), y_train,
            eval_set=[(X_train.astype('float32'), y_train), (X_valid.astype('float32'),y_valid)],
            verbose=100)
    print(f'({clf.best_ntree_limit}), ',end='')

        # SAVE MODEL, PREDICT VALID OOF
    models[i] = clf
    oof[valid_index] = clf.predict_proba(X_valid)[:,1]

    print()
# Out:
# #########################
# ### Fold 1
# #########################
# [0]	validation_0-logloss:0.69038	validation_1-logloss:0.69038
# [100]	validation_0-logloss:0.55738	validation_1-logloss:0.55655
# [200]	validation_0-logloss:0.52298	validation_1-logloss:0.52200
# [300]	validation_0-logloss:0.51026	validation_1-logloss:0.50964
# [400]	validation_0-logloss:0.50310	validation_1-logloss:0.50329
# [500]	validation_0-logloss:0.49825	validation_1-logloss:0.49952
# [600]	validation_0-logloss:0.49469	validation_1-logloss:0.49718
# [700]	validation_0-logloss:0.49176	validation_1-logloss:0.49561
# [800]	validation_0-logloss:0.48921	validation_1-logloss:0.49449
# [900]	validation_0-logloss:0.48694	validation_1-logloss:0.49363
# [1000]	validation_0-logloss:0.48492	validation_1-logloss:0.49297
# [1100]	validation_0-logloss:0.48303	validation_1-logloss:0.49244
# [1200]	validation_0-logloss:0.48130	validation_1-logloss:0.49208
# [1300]	validation_0-logloss:0.47965	validation_1-logloss:0.49177
# [1400]	validation_0-logloss:0.47804	validation_1-logloss:0.49150
# [1500]	validation_0-logloss:0.47652	validation_1-logloss:0.49128
# [1600]	validation_0-logloss:0.47497	validation_1-logloss:0.49106
# [1700]	validation_0-logloss:0.47353	validation_1-logloss:0.49093
# [1800]	validation_0-logloss:0.47215	validation_1-logloss:0.49080
# [1900]	validation_0-logloss:0.47077	validation_1-logloss:0.49071
# [2000]	validation_0-logloss:0.46936	validation_1-logloss:0.49057
# [2100]	validation_0-logloss:0.46809	validation_1-logloss:0.49050
# [2200]	validation_0-logloss:0.46679	validation_1-logloss:0.49046
# [2300]	validation_0-logloss:0.46555	validation_1-logloss:0.49039
# [2400]	validation_0-logloss:0.46436	validation_1-logloss:0.49031
# [2500]	validation_0-logloss:0.46315	validation_1-logloss:0.49021
# [2600]	validation_0-logloss:0.46195	validation_1-logloss:0.49018
# [2654]	validation_0-logloss:0.46129	validation_1-logloss:0.49018
# (2605),
# #########################
# ### Fold 2
# #########################
# [0]	validation_0-logloss:0.69037	validation_1-logloss:0.69037
# [100]	validation_0-logloss:0.55677	validation_1-logloss:0.55697
# [200]	validation_0-logloss:0.52243	validation_1-logloss:0.52351
# [300]	validation_0-logloss:0.50977	validation_1-logloss:0.51195
# [400]	validation_0-logloss:0.50253	validation_1-logloss:0.50603
# [500]	validation_0-logloss:0.49758	validation_1-logloss:0.50255
# [600]	validation_0-logloss:0.49395	validation_1-logloss:0.50044
# [700]	validation_0-logloss:0.49091	validation_1-logloss:0.49904
# [800]	validation_0-logloss:0.48834	validation_1-logloss:0.49806
# [900]	validation_0-logloss:0.48607	validation_1-logloss:0.49736
# [1000]	validation_0-logloss:0.48395	validation_1-logloss:0.49676
# [1100]	validation_0-logloss:0.48202	validation_1-logloss:0.49636
# [1200]	validation_0-logloss:0.48026	validation_1-logloss:0.49607
# [1300]	validation_0-logloss:0.47854	validation_1-logloss:0.49580
# [1400]	validation_0-logloss:0.47693	validation_1-logloss:0.49559
# [1500]	validation_0-logloss:0.47536	validation_1-logloss:0.49540
# [1600]	validation_0-logloss:0.47389	validation_1-logloss:0.49523
# [1700]	validation_0-logloss:0.47243	validation_1-logloss:0.49506
# [1800]	validation_0-logloss:0.47098	validation_1-logloss:0.49493
# [1900]	validation_0-logloss:0.46962	validation_1-logloss:0.49484
# [2000]	validation_0-logloss:0.46827	validation_1-logloss:0.49475
# [2100]	validation_0-logloss:0.46700	validation_1-logloss:0.49467
# [2200]	validation_0-logloss:0.46572	validation_1-logloss:0.49457
# [2300]	validation_0-logloss:0.46446	validation_1-logloss:0.49446
# [2347]	validation_0-logloss:0.46386	validation_1-logloss:0.49446
# (2299),
# #########################
# ### Fold 3
# #########################
# [0]	validation_0-logloss:0.69036	validation_1-logloss:0.69042
# [100]	validation_0-logloss:0.55618	validation_1-logloss:0.55988
# [200]	validation_0-logloss:0.52127	validation_1-logloss:0.52713
# [300]	validation_0-logloss:0.50826	validation_1-logloss:0.51575
# [400]	validation_0-logloss:0.50115	validation_1-logloss:0.51037
# [500]	validation_0-logloss:0.49637	validation_1-logloss:0.50718
# [600]	validation_0-logloss:0.49283	validation_1-logloss:0.50519
# [700]	validation_0-logloss:0.48980	validation_1-logloss:0.50381
# [800]	validation_0-logloss:0.48730	validation_1-logloss:0.50284
# [900]	validation_0-logloss:0.48507	validation_1-logloss:0.50207
# [1000]	validation_0-logloss:0.48300	validation_1-logloss:0.50152
# [1100]	validation_0-logloss:0.48114	validation_1-logloss:0.50107
# [1200]	validation_0-logloss:0.47933	validation_1-logloss:0.50070
# [1300]	validation_0-logloss:0.47763	validation_1-logloss:0.50038
# [1400]	validation_0-logloss:0.47601	validation_1-logloss:0.50016
# [1500]	validation_0-logloss:0.47453	validation_1-logloss:0.49993
# [1600]	validation_0-logloss:0.47292	validation_1-logloss:0.49975
# [1700]	validation_0-logloss:0.47147	validation_1-logloss:0.49961
# [1800]	validation_0-logloss:0.46998	validation_1-logloss:0.49948
# [1900]	validation_0-logloss:0.46852	validation_1-logloss:0.49935
# [2000]	validation_0-logloss:0.46717	validation_1-logloss:0.49924
# [2100]	validation_0-logloss:0.46583	validation_1-logloss:0.49914
# [2200]	validation_0-logloss:0.46452	validation_1-logloss:0.49907
# [2300]	validation_0-logloss:0.46318	validation_1-logloss:0.49904
# [2400]	validation_0-logloss:0.46198	validation_1-logloss:0.49899
# [2414]	validation_0-logloss:0.46179	validation_1-logloss:0.49898
# (2365),
# #########################
# ### Fold 4
# #########################
# [0]	validation_0-logloss:0.69037	validation_1-logloss:0.69038
# [100]	validation_0-logloss:0.55675	validation_1-logloss:0.55809
# [200]	validation_0-logloss:0.52221	validation_1-logloss:0.52450
# [300]	validation_0-logloss:0.50946	validation_1-logloss:0.51270
# [400]	validation_0-logloss:0.50240	validation_1-logloss:0.50676
# [500]	validation_0-logloss:0.49745	validation_1-logloss:0.50308
# [600]	validation_0-logloss:0.49381	validation_1-logloss:0.50079
# [700]	validation_0-logloss:0.49081	validation_1-logloss:0.49928
# [800]	validation_0-logloss:0.48824	validation_1-logloss:0.49832
# [900]	validation_0-logloss:0.48589	validation_1-logloss:0.49756
# [1000]	validation_0-logloss:0.48382	validation_1-logloss:0.49695
# [1100]	validation_0-logloss:0.48192	validation_1-logloss:0.49654
# [1200]	validation_0-logloss:0.48013	validation_1-logloss:0.49615
# [1300]	validation_0-logloss:0.47842	validation_1-logloss:0.49587
# [1400]	validation_0-logloss:0.47675	validation_1-logloss:0.49559
# [1500]	validation_0-logloss:0.47519	validation_1-logloss:0.49536
# [1600]	validation_0-logloss:0.47363	validation_1-logloss:0.49520
# [1700]	validation_0-logloss:0.47216	validation_1-logloss:0.49507
# [1800]	validation_0-logloss:0.47073	validation_1-logloss:0.49489
# [1900]	validation_0-logloss:0.46934	validation_1-logloss:0.49478
# [2000]	validation_0-logloss:0.46800	validation_1-logloss:0.49470
# [2100]	validation_0-logloss:0.46670	validation_1-logloss:0.49463
# [2200]	validation_0-logloss:0.46535	validation_1-logloss:0.49457
# [2300]	validation_0-logloss:0.46405	validation_1-logloss:0.49450
# [2400]	validation_0-logloss:0.46281	validation_1-logloss:0.49439
# [2500]	validation_0-logloss:0.46158	validation_1-logloss:0.49437
# [2600]	validation_0-logloss:0.46041	validation_1-logloss:0.49431
# [2700]	validation_0-logloss:0.45925	validation_1-logloss:0.49425
# [2800]	validation_0-logloss:0.45807	validation_1-logloss:0.49423
# [2832]	validation_0-logloss:0.45769	validation_1-logloss:0.49424
# (2784),
# #########################
# ### Fold 5
# #########################
# [0]	validation_0-logloss:0.69037	validation_1-logloss:0.69039
# [100]	validation_0-logloss:0.55655	validation_1-logloss:0.55795
# [200]	validation_0-logloss:0.52169	validation_1-logloss:0.52469
# [300]	validation_0-logloss:0.50867	validation_1-logloss:0.51321
# [400]	validation_0-logloss:0.50158	validation_1-logloss:0.50769
# [500]	validation_0-logloss:0.49673	validation_1-logloss:0.50438
# [600]	validation_0-logloss:0.49314	validation_1-logloss:0.50239
# [700]	validation_0-logloss:0.49015	validation_1-logloss:0.50094
# [800]	validation_0-logloss:0.48764	validation_1-logloss:0.49997
# [900]	validation_0-logloss:0.48541	validation_1-logloss:0.49926
# [1000]	validation_0-logloss:0.48332	validation_1-logloss:0.49874
# [1100]	validation_0-logloss:0.48141	validation_1-logloss:0.49830
# [1200]	validation_0-logloss:0.47961	validation_1-logloss:0.49796
# [1300]	validation_0-logloss:0.47792	validation_1-logloss:0.49767
# [1400]	validation_0-logloss:0.47625	validation_1-logloss:0.49739
# [1500]	validation_0-logloss:0.47466	validation_1-logloss:0.49724
# [1600]	validation_0-logloss:0.47320	validation_1-logloss:0.49710
# [1700]	validation_0-logloss:0.47172	validation_1-logloss:0.49696
# [1800]	validation_0-logloss:0.47029	validation_1-logloss:0.49682
# [1900]	validation_0-logloss:0.46891	validation_1-logloss:0.49671
# [2000]	validation_0-logloss:0.46756	validation_1-logloss:0.49658
# [2100]	validation_0-logloss:0.46618	validation_1-logloss:0.49650
# [2200]	validation_0-logloss:0.46494	validation_1-logloss:0.49638
# [2300]	validation_0-logloss:0.46366	validation_1-logloss:0.49630
# [2400]	validation_0-logloss:0.46248	validation_1-logloss:0.49627
# [2500]	validation_0-logloss:0.46126	validation_1-logloss:0.49619
# [2600]	validation_0-logloss:0.46010	validation_1-logloss:0.49614
# [2700]	validation_0-logloss:0.45893	validation_1-logloss:0.49608
# [2800]	validation_0-logloss:0.45779	validation_1-logloss:0.49603
# [2900]	validation_0-logloss:0.45670	validation_1-logloss:0.49598
# [2970]	validation_0-logloss:0.45592	validation_1-logloss:0.49597
# (2921),

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def plot_feature_importance(importance,names,model_type):

    #Create arrays from feature importance and feature names
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    #Create a DataFrame using a Dictionary
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)

    #Sort the DataFrame in order decreasing feature importance
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_df = fi_df.tail(50)
    #Define size of bar plot
    plt.figure(figsize=(20,10))
    #Plot Searborn bar chart
    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
    #Add chart labels
    plt.title(model_type + 'FEATURE IMPORTANCE')
    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')

# %%
feat_imp = {}
for k, v in models.items():
    for x, y in zip(v.feature_importances_, v.feature_names_in_):
        if y not in feat_imp:
            feat_imp[y] = x
        else:
            feat_imp[y]+=x
plot_feature_importance(list(feat_imp.values()),list(feat_imp.keys()),'')

# %%
scores = []; thresholds = []
best_score = 0; best_threshold = 0

for threshold in np.arange(0.4,0.9,0.01):
    print(f'{threshold:.02f}, ',end='')
    preds = (oof>threshold).astype('int')
    m = f1_score(X['correct'], preds, average='macro')
    scores.append(m)
    thresholds.append(threshold)
    if m>best_score:
        best_score = m
        best_threshold = threshold
# Out:
# 0.40, 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.50, 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.60, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.70, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.80, 0.81, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89,

# %%
import matplotlib.pyplot as plt

# PLOT THRESHOLD VS. F1_SCORE
plt.figure(figsize=(20,5))
plt.plot(thresholds,scores,'-o',color='blue')
plt.scatter([best_threshold], [best_score], color='blue', s=300, alpha=1)
plt.xlabel('Threshold',size=14)
plt.ylabel('Validation F1 Score',size=14)
plt.title(f'Threshold vs. F1_Score with Best F1_Score = {best_score:.4f} at Best Threshold = {best_threshold:.3}',size=18)
plt.show()

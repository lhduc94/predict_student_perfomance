# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc
from collections import Counter

# %%
class Config:
    TRAIN_PATH = '../inputs/train.csv'
    TEST_PATH = '../inputs/test.csv'
    TRAIN_LABELS = '../inputs/train_labels.csv'
    SAMPLE_SUBMISSION = '../inputs/sample_submission.csv'

# %%
train_df = pd.read_csv(Config.TRAIN_PATH)
train_labels = pd.read_csv(Config.TRAIN_LABELS)

# %%
train_labels['question'] = train_labels['session_id'].str.split('q').str[-1].astype('int8')
train_labels['session'] = train_labels['session_id'].str.split('_').str[0]
train_labels.head()
# Out:
#              session_id  correct  question            session
# 0  20090312431273200_q1        1         1  20090312431273200
# 1  20090312433251036_q1        0         1  20090312433251036
# 2  20090314121766812_q1        1         1  20090314121766812
# 3  20090314363702160_q1        1         1  20090314363702160
# 4  20090314441803444_q1        1         1  20090314441803444

# %%
train_labels['session'] = train_labels['session'].astype('int64')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
CATS = ['event_name', 'fqid', 'room_fqid', 'text']
NUMS = ['elapsed_time','page','room_coor_x', 'room_coor_y',
        'screen_coor_x', 'screen_coor_y', 'hover_duration']
EVENTS = ['navigate_click','person_click','cutscene_click','object_click',
          'map_hover','notification_click','map_click','observation_click',
          'checkpoint']
ROOMS = ['historicalsociety',
          'kohlcenter',
          'capitol_0',
          'humanecology',
          'drycleaner',
          'library',
          'capitol_1',
          'wildlife',
          'flaghouse',
          'capitol_2']

# %%
def groupby_apply_elapsed_time(g):
    res = {}
    diff = np.diff(g['elapsed_time'].values)
    res['elapsed_time_diff_mean'] = np.mean(diff)
    res['elapsed_time_diff_std'] = np.std(diff)
    res['elapsed_time_positive'] = len(diff[diff>0])
    res['elapsed_time_negative'] = len(diff) - res['elapsed_time_positive']
    res['start-end'] = g['elapsed_time'].values[-1] - g['elapsed_time'].values[0]
    return pd.Series(res)

# %%
def feature_engineer(train):
    dfs = []
    tmp = train.groupby(['session_id','level_group']).apply(groupby_apply_elapsed_time)
    dfs.append(tmp)
    for c in EVENTS:
        train[c] = (train.event_name == c)
    train['main_room'] = train['room_fqid'].str.split('.').str[1]
    for c in ROOMS:
        train[c] = (train.main_room == c)
    for c1 in ROOMS:
        for c2 in EVENTS:
            train[f'{c1}_{c2}'] = train[c1] + train[c2]
            tmp = train.groupby(['session_id','level_group'])[f'{c1}_{c2}'].sum()
            tmp.name = tmp.name + '_sum'
            dfs.append(tmp)
    for c in EVENTS +ROOMS+ ['elapsed_time']:
        tmp = train.groupby(['session_id','level_group'])[c].agg('sum')
        tmp.name = tmp.name + '_sum'
        dfs.append(tmp)
    for c in CATS:
        tmp = train.groupby(['session_id','level_group'])[c].agg('nunique')
        tmp.name = tmp.name + '_nunique'
        dfs.append(tmp)
    for c in NUMS + EVENTS + ROOMS:
        tmp = train.groupby(['session_id','level_group'])[c].agg('mean')
        tmp.name = tmp.name + '_mean'
        dfs.append(tmp)
    for c in NUMS+ EVENTS + ROOMS:
        tmp = train.groupby(['session_id','level_group'])[c].agg('std')
        tmp.name = tmp.name + '_std'
        dfs.append(tmp)
    train.drop(columns=EVENTS+ROOMS,inplace=True)

    df = pd.concat(dfs,axis=1)
    df = df.fillna(-1)
    df = df.reset_index()
    df = df.set_index('session_id')
    return df

# %%
# %%time
df = feature_engineer(train_df)
print( df.shape )
df.head()
# Out:
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# C:\Users\ADMIN\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:214: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead.
#   warnings.warn(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25348\3546455000.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train[f'{c1}_{c2}'] = train[c1] + train[c2]
# (35337, 172)
# CPU times: total: 3min 2s
# Wall time: 3min 2s
#                   level_group  elapsed_time_diff_mean  elapsed_time_diff_std  \
# session_id
# 20090312431273200         0-4             1188.170732            2447.579017
# 20090312431273200       13-22             1040.446301            1985.279111
# 20090312431273200        5-12              941.525424             714.119241
# 20090312433251036         0-4             1693.855072            3504.819590
# 20090312433251036       13-22             2036.150463           10339.121375
#
#                    elapsed_time_positive  elapsed_time_negative  start-end  \
# session_id
# 20090312431273200                  161.0                    3.0   194860.0
# 20090312431273200                  411.0                    8.0   435947.0
# 20090312431273200                  291.0                    4.0   277750.0
# 20090312433251036                  136.0                    2.0   233752.0
# 20090312433251036                 1267.0                   29.0  2638851.0
#
#                    historicalsociety_navigate_click_sum  \
# session_id
# 20090312431273200                                   153
# 20090312431273200                                   295
# 20090312431273200                                   197
# 20090312433251036                                   119
# 20090312433251036                                   917
#
#                    historicalsociety_person_click_sum  \
# session_id
# 20090312431273200                                 130
# 20090312431273200                                 317
# 20090312431273200                                 199
# 20090312433251036                                 105
# 20090312433251036                                 634
#
#                    historicalsociety_cutscene_click_sum  \
# session_id
# 20090312431273200                                   132
# 20090312431273200                                   232
# 20090312431273200                                   151
# 20090312433251036                                   107
# 20090312433251036                                   531
#
#                    historicalsociety_object_click_sum  ...  \
# session_id                                             ...
# 20090312431273200                                 133  ...
# 20090312431273200                                 246  ...
# 20090312431273200                                 172  ...
# 20090312433251036                                 115  ...
# 20090312433251036                                 578  ...
#
#                    historicalsociety_std  kohlcenter_std  capitol_0_std  \
# session_id
# 20090312431273200               0.410055        0.401218       0.109760
# 20090312431273200               0.497842        0.000000       0.000000
# 20090312431273200               0.500744        0.000000       0.171991
# 20090312433251036               0.431407        0.422493       0.119517
# 20090312433251036               0.491914        0.271684       0.000000
#
#                    humanecology_std  drycleaner_std  library_std  \
# session_id
# 20090312431273200          0.000000        0.000000     0.000000
# 20090312431273200          0.000000        0.000000     0.293894
# 20090312431273200          0.356344        0.315267     0.362904
# 20090312433251036          0.000000        0.000000     0.000000
# 20090312433251036          0.236403        0.208456     0.305490
#
#                    capitol_1_std  wildlife_std  flaghouse_std  capitol_2_std
# session_id
# 20090312431273200       0.000000      0.000000       0.000000       0.000000
# 20090312431273200       0.152637      0.432144       0.265619       0.068924
# 20090312431273200       0.205262      0.000000       0.000000       0.000000
# 20090312433251036       0.000000      0.000000       0.000000       0.000000
# 20090312433251036       0.067884      0.326310       0.194434       0.343418
#
# [5 rows x 172 columns]

# %%
for x in df.columns:
    print(x)
# Out:
# level_group
# elapsed_time_diff_mean
# elapsed_time_diff_std
# elapsed_time_positive
# elapsed_time_negative
# start-end
# historicalsociety_navigate_click_sum
# historicalsociety_person_click_sum
# historicalsociety_cutscene_click_sum
# historicalsociety_object_click_sum
# historicalsociety_map_hover_sum
# historicalsociety_notification_click_sum
# historicalsociety_map_click_sum
# historicalsociety_observation_click_sum
# historicalsociety_checkpoint_sum
# kohlcenter_navigate_click_sum
# kohlcenter_person_click_sum
# kohlcenter_cutscene_click_sum
# kohlcenter_object_click_sum
# kohlcenter_map_hover_sum
# kohlcenter_notification_click_sum
# kohlcenter_map_click_sum
# kohlcenter_observation_click_sum
# kohlcenter_checkpoint_sum
# capitol_0_navigate_click_sum
# capitol_0_person_click_sum
# capitol_0_cutscene_click_sum
# capitol_0_object_click_sum
# capitol_0_map_hover_sum
# capitol_0_notification_click_sum
# capitol_0_map_click_sum
# capitol_0_observation_click_sum
# capitol_0_checkpoint_sum
# humanecology_navigate_click_sum
# humanecology_person_click_sum
# humanecology_cutscene_click_sum
# humanecology_object_click_sum
# humanecology_map_hover_sum
# humanecology_notification_click_sum
# humanecology_map_click_sum
# humanecology_observation_click_sum
# humanecology_checkpoint_sum
# drycleaner_navigate_click_sum
# drycleaner_person_click_sum
# drycleaner_cutscene_click_sum
# drycleaner_object_click_sum
# drycleaner_map_hover_sum
# drycleaner_notification_click_sum
# drycleaner_map_click_sum
# drycleaner_observation_click_sum
# drycleaner_checkpoint_sum
# library_navigate_click_sum
# library_person_click_sum
# library_cutscene_click_sum
# library_object_click_sum
# library_map_hover_sum
# library_notification_click_sum
# library_map_click_sum
# library_observation_click_sum
# library_checkpoint_sum
# capitol_1_navigate_click_sum
# capitol_1_person_click_sum
# capitol_1_cutscene_click_sum
# capitol_1_object_click_sum
# capitol_1_map_hover_sum
# capitol_1_notification_click_sum
# capitol_1_map_click_sum
# capitol_1_observation_click_sum
# capitol_1_checkpoint_sum
# wildlife_navigate_click_sum
# wildlife_person_click_sum
# wildlife_cutscene_click_sum
# wildlife_object_click_sum
# wildlife_map_hover_sum
# wildlife_notification_click_sum
# wildlife_map_click_sum
# wildlife_observation_click_sum
# wildlife_checkpoint_sum
# flaghouse_navigate_click_sum
# flaghouse_person_click_sum
# flaghouse_cutscene_click_sum
# flaghouse_object_click_sum
# flaghouse_map_hover_sum
# flaghouse_notification_click_sum
# flaghouse_map_click_sum
# flaghouse_observation_click_sum
# flaghouse_checkpoint_sum
# capitol_2_navigate_click_sum
# capitol_2_person_click_sum
# capitol_2_cutscene_click_sum
# capitol_2_object_click_sum
# capitol_2_map_hover_sum
# capitol_2_notification_click_sum
# capitol_2_map_click_sum
# capitol_2_observation_click_sum
# capitol_2_checkpoint_sum
# navigate_click_sum
# person_click_sum
# cutscene_click_sum
# object_click_sum
# map_hover_sum
# notification_click_sum
# map_click_sum
# observation_click_sum
# checkpoint_sum
# historicalsociety_sum
# kohlcenter_sum
# capitol_0_sum
# humanecology_sum
# drycleaner_sum
# library_sum
# capitol_1_sum
# wildlife_sum
# flaghouse_sum
# capitol_2_sum
# elapsed_time_sum
# event_name_nunique
# fqid_nunique
# room_fqid_nunique
# text_nunique
# elapsed_time_mean
# page_mean
# room_coor_x_mean
# room_coor_y_mean
# screen_coor_x_mean
# screen_coor_y_mean
# hover_duration_mean
# navigate_click_mean
# person_click_mean
# cutscene_click_mean
# object_click_mean
# map_hover_mean
# notification_click_mean
# map_click_mean
# observation_click_mean
# checkpoint_mean
# historicalsociety_mean
# kohlcenter_mean
# capitol_0_mean
# humanecology_mean
# drycleaner_mean
# library_mean
# capitol_1_mean
# wildlife_mean
# flaghouse_mean
# capitol_2_mean
# elapsed_time_std
# page_std
# room_coor_x_std
# room_coor_y_std
# screen_coor_x_std
# screen_coor_y_std
# hover_duration_std
# navigate_click_std
# person_click_std
# cutscene_click_std
# object_click_std
# map_hover_std
# notification_click_std
# map_click_std
# observation_click_std
# checkpoint_std
# historicalsociety_std
# kohlcenter_std
# capitol_0_std
# humanecology_std
# drycleaner_std
# library_std
# capitol_1_std
# wildlife_std
# flaghouse_std
# capitol_2_std

# %%
from sklearn.model_selection import KFold, GroupKFold
from xgboost import XGBClassifier
from sklearn.metrics import f1_score

# %%
FEATURES = [c for c in df.columns if c not in [ 'level_group']]
print('We will train with', len(FEATURES) ,'features')
ALL_USERS = df.index.unique()
print('We will train with', len(ALL_USERS) ,'users info')
# Out:
# We will train with 171 features
# We will train with 11779 users info

# %%
n_splits=5
gkf = GroupKFold(n_splits=n_splits)
oof = pd.DataFrame(data=np.zeros((len(ALL_USERS),18)), index=ALL_USERS)
models = {}

# COMPUTE CV SCORE WITH 5 GROUP K FOLD
for i, (train_index, test_index) in enumerate(gkf.split(X=df, groups=df.index)):
    print('#'*25)
    print('### Fold',i+1)
    print('#'*25)

    xgb_params = {
        'objective' : 'binary:logistic',
        'eval_metric':'logloss',
        'learning_rate': 0.01,
        'max_depth': 4,
        'n_estimators': 1500,
        'early_stopping_rounds': 50,
        'tree_method':'hist',
        'subsample':0.8,
        'colsample_bytree': 0.8,
        'colsample_bylevel': 0.4,
        'use_label_encoder' : False}

    # ITERATE THRU QUESTIONS 1 THRU 18
    for t in range(1,19):

        # USE THIS TRAIN DATA WITH THESE QUESTIONS
        if t<=3: grp = '0-4'
        elif t<=13: grp = '5-12'
        elif t<=22: grp = '13-22'

        # TRAIN DATA
        train_x = df.iloc[train_index]
        train_x = train_x.loc[train_x.level_group == grp]
        train_users = train_x.index.values
        train_y = train_labels.loc[train_labels.question==t].set_index('session').loc[train_users]

        # VALID DATA
        valid_x = df.iloc[test_index]
        valid_x = valid_x.loc[valid_x.level_group == grp]
        valid_users = valid_x.index.values
        valid_y = train_labels.loc[train_labels.question==t].set_index('session').loc[valid_users]

        # TRAIN MODEL
        clf =  XGBClassifier(**xgb_params)
        clf.fit(train_x[FEATURES].astype('float32'), train_y['correct'],
                eval_set=[(train_x[FEATURES].astype('float32'), train_y['correct']), (valid_x[FEATURES].astype('float32'), valid_y['correct']) ],
                verbose=100)
        print(f'{t}({clf.best_ntree_limit}), ',end='')

        # SAVE MODEL, PREDICT VALID OOF
        models[f'{i}_{grp}_{t}'] = clf
        oof.loc[valid_users, t-1] = clf.predict_proba(valid_x[FEATURES].astype('float32'))[:,1]

    print()
# Out:
# #########################
# ### Fold 1
# #########################
# [0]	validation_0-logloss:0.69057	validation_1-logloss:0.69051
# [100]	validation_0-logloss:0.56699	validation_1-logloss:0.56760
# [200]	validation_0-logloss:0.53265	validation_1-logloss:0.53979
# [300]	validation_0-logloss:0.51525	validation_1-logloss:0.53025
# [400]	validation_0-logloss:0.50344	validation_1-logloss:0.52624
# [500]	validation_0-logloss:0.49355	validation_1-logloss:0.52375
# [600]	validation_0-logloss:0.48433	validation_1-logloss:0.52197
# [700]	validation_0-logloss:0.47610	validation_1-logloss:0.52078
# [800]	validation_0-logloss:0.46823	validation_1-logloss:0.51939
# [900]	validation_0-logloss:0.46116	validation_1-logloss:0.51841
# [1000]	validation_0-logloss:0.45437	validation_1-logloss:0.51823
# [1100]	validation_0-logloss:0.44806	validation_1-logloss:0.51799
# [1162]	validation_0-logloss:0.44412	validation_1-logloss:0.51791
# 1(1113), [0]	validation_0-logloss:0.68400	validation_1-logloss:0.68398
# [100]	validation_0-logloss:0.24473	validation_1-logloss:0.24401
# [200]	validation_0-logloss:0.13157	validation_1-logloss:0.13239
# [300]	validation_0-logloss:0.09565	validation_1-logloss:0.09973
# [400]	validation_0-logloss:0.08153	validation_1-logloss:0.08991
# [500]	validation_0-logloss:0.07336	validation_1-logloss:0.08682
# [600]	validation_0-logloss:0.06720	validation_1-logloss:0.08587
# [700]	validation_0-logloss:0.06187	validation_1-logloss:0.08566
# [785]	validation_0-logloss:0.05784	validation_1-logloss:0.08574
# 2(736), [0]	validation_0-logloss:0.68558	validation_1-logloss:0.68563
# [100]	validation_0-logloss:0.32822	validation_1-logloss:0.33241
# [200]	validation_0-logloss:0.24334	validation_1-logloss:0.25327
# [300]	validation_0-logloss:0.21728	validation_1-logloss:0.23468
# [400]	validation_0-logloss:0.20561	validation_1-logloss:0.23024
# [500]	validation_0-logloss:0.19755	validation_1-logloss:0.22969
# [509]	validation_0-logloss:0.19687	validation_1-logloss:0.22965
# 3(460), [0]	validation_0-logloss:0.68890	validation_1-logloss:0.68886
# [100]	validation_0-logloss:0.48897	validation_1-logloss:0.49014
# [200]	validation_0-logloss:0.44140	validation_1-logloss:0.44792
# [300]	validation_0-logloss:0.42320	validation_1-logloss:0.43705
# [400]	validation_0-logloss:0.41121	validation_1-logloss:0.43299
# [500]	validation_0-logloss:0.40216	validation_1-logloss:0.43122
# [600]	validation_0-logloss:0.39362	validation_1-logloss:0.43049
# [700]	validation_0-logloss:0.38608	validation_1-logloss:0.43019
# [800]	validation_0-logloss:0.37883	validation_1-logloss:0.42985
# [874]	validation_0-logloss:0.37341	validation_1-logloss:0.42975
# 4(826), [0]	validation_0-logloss:0.69225	validation_1-logloss:0.69228
# [100]	validation_0-logloss:0.64552	validation_1-logloss:0.65096
# [200]	validation_0-logloss:0.62773	validation_1-logloss:0.64152
# [300]	validation_0-logloss:0.61568	validation_1-logloss:0.63838
# [400]	validation_0-logloss:0.60591	validation_1-logloss:0.63721
# [500]	validation_0-logloss:0.59686	validation_1-logloss:0.63682
# [580]	validation_0-logloss:0.58984	validation_1-logloss:0.63677
# 5(532), [0]	validation_0-logloss:0.68948	validation_1-logloss:0.68966
# [100]	validation_0-logloss:0.51803	validation_1-logloss:0.53335
# [200]	validation_0-logloss:0.47845	validation_1-logloss:0.50581
# [300]	validation_0-logloss:0.46248	validation_1-logloss:0.50031
# [400]	validation_0-logloss:0.45185	validation_1-logloss:0.49811
# [500]	validation_0-logloss:0.44272	validation_1-logloss:0.49684
# [600]	validation_0-logloss:0.43431	validation_1-logloss:0.49608
# [700]	validation_0-logloss:0.42661	validation_1-logloss:0.49572
# [710]	validation_0-logloss:0.42578	validation_1-logloss:0.49583
# 6(661), [0]	validation_0-logloss:0.69044	validation_1-logloss:0.69068
# [100]	validation_0-logloss:0.56222	validation_1-logloss:0.58062
# [200]	validation_0-logloss:0.53094	validation_1-logloss:0.56396
# [300]	validation_0-logloss:0.51652	validation_1-logloss:0.56070
# [400]	validation_0-logloss:0.50674	validation_1-logloss:0.55991
# [500]	validation_0-logloss:0.49783	validation_1-logloss:0.55982
# [590]	validation_0-logloss:0.49015	validation_1-logloss:0.55964
# 7(542), [0]	validation_0-logloss:0.69232	validation_1-logloss:0.69234
# [100]	validation_0-logloss:0.64944	validation_1-logloss:0.65660
# [200]	validation_0-logloss:0.63437	validation_1-logloss:0.64985
# [300]	validation_0-logloss:0.62461	validation_1-logloss:0.64898
# [398]	validation_0-logloss:0.61625	validation_1-logloss:0.64908
# 8(349), [0]	validation_0-logloss:0.69029	validation_1-logloss:0.69042
# [100]	validation_0-logloss:0.55626	validation_1-logloss:0.57134
# [200]	validation_0-logloss:0.52446	validation_1-logloss:0.55138
# [300]	validation_0-logloss:0.50997	validation_1-logloss:0.54725
# [400]	validation_0-logloss:0.49966	validation_1-logloss:0.54591
# [500]	validation_0-logloss:0.49075	validation_1-logloss:0.54554
# [544]	validation_0-logloss:0.48699	validation_1-logloss:0.54555
# 9(496), [0]	validation_0-logloss:0.69241	validation_1-logloss:0.69242
# [100]	validation_0-logloss:0.65351	validation_1-logloss:0.65579
# [200]	validation_0-logloss:0.63703	validation_1-logloss:0.64592
# [300]	validation_0-logloss:0.62526	validation_1-logloss:0.64214
# [400]	validation_0-logloss:0.61536	validation_1-logloss:0.64064
# [500]	validation_0-logloss:0.60657	validation_1-logloss:0.63982
# [600]	validation_0-logloss:0.59828	validation_1-logloss:0.63953
# [609]	validation_0-logloss:0.59756	validation_1-logloss:0.63951
# 10(561), [0]	validation_0-logloss:0.69179	validation_1-logloss:0.69190
# [100]	validation_0-logloss:0.62497	validation_1-logloss:0.63489
# [200]	validation_0-logloss:0.60497	validation_1-logloss:0.62488
# [300]	validation_0-logloss:0.59339	validation_1-logloss:0.62198
# [400]	validation_0-logloss:0.58365	validation_1-logloss:0.62086
# [500]	validation_0-logloss:0.57464	validation_1-logloss:0.62045
# [600]	validation_0-logloss:0.56660	validation_1-logloss:0.62004
# [664]	validation_0-logloss:0.56162	validation_1-logloss:0.62022
# 11(615), [0]	validation_0-logloss:0.68783	validation_1-logloss:0.68795
# [100]	validation_0-logloss:0.43939	validation_1-logloss:0.44850
# [200]	validation_0-logloss:0.38534	validation_1-logloss:0.40315
# [300]	validation_0-logloss:0.36792	validation_1-logloss:0.39525
# [400]	validation_0-logloss:0.35781	validation_1-logloss:0.39408
# [477]	validation_0-logloss:0.35162	validation_1-logloss:0.39406
# 12(428), [0]	validation_0-logloss:0.69043	validation_1-logloss:0.69050
# [100]	validation_0-logloss:0.56160	validation_1-logloss:0.56779
# [200]	validation_0-logloss:0.52995	validation_1-logloss:0.54417
# [300]	validation_0-logloss:0.51598	validation_1-logloss:0.53891
# [400]	validation_0-logloss:0.50624	validation_1-logloss:0.53730
# [500]	validation_0-logloss:0.49770	validation_1-logloss:0.53682
# [596]	validation_0-logloss:0.49026	validation_1-logloss:0.53697
# 13(548), [0]	validation_0-logloss:0.69072	validation_1-logloss:0.69084
# [100]	validation_0-logloss:0.57464	validation_1-logloss:0.58619
# [200]	validation_0-logloss:0.54535	validation_1-logloss:0.56730
# [300]	validation_0-logloss:0.53133	validation_1-logloss:0.56310
# [400]	validation_0-logloss:0.52056	validation_1-logloss:0.56181
# [500]	validation_0-logloss:0.51133	validation_1-logloss:0.56134
# [600]	validation_0-logloss:0.50314	validation_1-logloss:0.56107
# [624]	validation_0-logloss:0.50127	validation_1-logloss:0.56110
# 14(575), [0]	validation_0-logloss:0.69232	validation_1-logloss:0.69242
# [100]	validation_0-logloss:0.64782	validation_1-logloss:0.65950
# [200]	validation_0-logloss:0.62955	validation_1-logloss:0.65166
# [300]	validation_0-logloss:0.61689	validation_1-logloss:0.64885
# [400]	validation_0-logloss:0.60630	validation_1-logloss:0.64734
# [500]	validation_0-logloss:0.59712	validation_1-logloss:0.64694
# [600]	validation_0-logloss:0.58837	validation_1-logloss:0.64684
# [667]	validation_0-logloss:0.58299	validation_1-logloss:0.64683
# 15(618), [0]	validation_0-logloss:0.69070	validation_1-logloss:0.69077
# [100]	validation_0-logloss:0.58022	validation_1-logloss:0.58850
# [200]	validation_0-logloss:0.55598	validation_1-logloss:0.57269
# [300]	validation_0-logloss:0.54502	validation_1-logloss:0.57060
# [400]	validation_0-logloss:0.53670	validation_1-logloss:0.57041
# [406]	validation_0-logloss:0.53622	validation_1-logloss:0.57040
# 16(358), [0]	validation_0-logloss:0.69156	validation_1-logloss:0.69157
# [100]	validation_0-logloss:0.61483	validation_1-logloss:0.62059
# [200]	validation_0-logloss:0.59438	validation_1-logloss:0.60871
# [300]	validation_0-logloss:0.58306	validation_1-logloss:0.60683
# [400]	validation_0-logloss:0.57358	validation_1-logloss:0.60662
# [500]	validation_0-logloss:0.56415	validation_1-logloss:0.60652
# [506]	validation_0-logloss:0.56358	validation_1-logloss:0.60664
# 17(457), [0]	validation_0-logloss:0.68497	validation_1-logloss:0.68495
# [100]	validation_0-logloss:0.29483	validation_1-logloss:0.29634
# [200]	validation_0-logloss:0.19895	validation_1-logloss:0.20406
# [300]	validation_0-logloss:0.16922	validation_1-logloss:0.17994
# [400]	validation_0-logloss:0.15612	validation_1-logloss:0.17386
# [500]	validation_0-logloss:0.14718	validation_1-logloss:0.17203
# [600]	validation_0-logloss:0.14040	validation_1-logloss:0.17180
# [667]	validation_0-logloss:0.13602	validation_1-logloss:0.17188
# 18(619),
# #########################
# ### Fold 2
# #########################
# [0]	validation_0-logloss:0.69062	validation_1-logloss:0.69048
# [100]	validation_0-logloss:0.56910	validation_1-logloss:0.56399
# [200]	validation_0-logloss:0.53513	validation_1-logloss:0.53320
# [300]	validation_0-logloss:0.51782	validation_1-logloss:0.52263
# [400]	validation_0-logloss:0.50564	validation_1-logloss:0.51793
# [500]	validation_0-logloss:0.49542	validation_1-logloss:0.51531
# [600]	validation_0-logloss:0.48645	validation_1-logloss:0.51328
# [700]	validation_0-logloss:0.47846	validation_1-logloss:0.51205
# [800]	validation_0-logloss:0.47081	validation_1-logloss:0.51104
# [900]	validation_0-logloss:0.46363	validation_1-logloss:0.51024
# [1000]	validation_0-logloss:0.45694	validation_1-logloss:0.51013
# [1016]	validation_0-logloss:0.45593	validation_1-logloss:0.51013
# 1(967), [0]	validation_0-logloss:0.68400	validation_1-logloss:0.68405
# [100]	validation_0-logloss:0.24375	validation_1-logloss:0.24701
# [200]	validation_0-logloss:0.12983	validation_1-logloss:0.13773
# [300]	validation_0-logloss:0.09321	validation_1-logloss:0.10738
# [400]	validation_0-logloss:0.07880	validation_1-logloss:0.09984
# [500]	validation_0-logloss:0.07096	validation_1-logloss:0.09881
# [554]	validation_0-logloss:0.06748	validation_1-logloss:0.09896
# 2(505), [0]	validation_0-logloss:0.68567	validation_1-logloss:0.68562
# [100]	validation_0-logloss:0.33038	validation_1-logloss:0.32708
# [200]	validation_0-logloss:0.24637	validation_1-logloss:0.24433
# [300]	validation_0-logloss:0.22077	validation_1-logloss:0.22254
# [400]	validation_0-logloss:0.20902	validation_1-logloss:0.21655
# [500]	validation_0-logloss:0.20089	validation_1-logloss:0.21423
# [600]	validation_0-logloss:0.19372	validation_1-logloss:0.21304
# [700]	validation_0-logloss:0.18716	validation_1-logloss:0.21238
# [773]	validation_0-logloss:0.18276	validation_1-logloss:0.21235
# 3(725), [0]	validation_0-logloss:0.68885	validation_1-logloss:0.68905
# [100]	validation_0-logloss:0.48540	validation_1-logloss:0.49701
# [200]	validation_0-logloss:0.43690	validation_1-logloss:0.45971
# [300]	validation_0-logloss:0.41828	validation_1-logloss:0.45104
# [400]	validation_0-logloss:0.40666	validation_1-logloss:0.44871
# [500]	validation_0-logloss:0.39701	validation_1-logloss:0.44781
# [554]	validation_0-logloss:0.39231	validation_1-logloss:0.44783
# 4(505), [0]	validation_0-logloss:0.69222	validation_1-logloss:0.69230
# [100]	validation_0-logloss:0.64412	validation_1-logloss:0.65643
# [200]	validation_0-logloss:0.62618	validation_1-logloss:0.64937
# [300]	validation_0-logloss:0.61387	validation_1-logloss:0.64692
# [400]	validation_0-logloss:0.60387	validation_1-logloss:0.64608
# [458]	validation_0-logloss:0.59862	validation_1-logloss:0.64611
# 5(409), [0]	validation_0-logloss:0.68954	validation_1-logloss:0.68959
# [100]	validation_0-logloss:0.52027	validation_1-logloss:0.52720
# [200]	validation_0-logloss:0.48094	validation_1-logloss:0.49671
# [300]	validation_0-logloss:0.46446	validation_1-logloss:0.49027
# [400]	validation_0-logloss:0.45339	validation_1-logloss:0.48852
# [500]	validation_0-logloss:0.44409	validation_1-logloss:0.48829
# [510]	validation_0-logloss:0.44331	validation_1-logloss:0.48826
# 6(462), [0]	validation_0-logloss:0.69055	validation_1-logloss:0.69055
# [100]	validation_0-logloss:0.56655	validation_1-logloss:0.57001
# [200]	validation_0-logloss:0.53598	validation_1-logloss:0.54687
# [300]	validation_0-logloss:0.52139	validation_1-logloss:0.54125
# [400]	validation_0-logloss:0.51100	validation_1-logloss:0.53930
# [500]	validation_0-logloss:0.50221	validation_1-logloss:0.53850
# [600]	validation_0-logloss:0.49342	validation_1-logloss:0.53818
# [700]	validation_0-logloss:0.48560	validation_1-logloss:0.53790
# [729]	validation_0-logloss:0.48338	validation_1-logloss:0.53799
# 7(681), [0]	validation_0-logloss:0.69227	validation_1-logloss:0.69241
# [100]	validation_0-logloss:0.64788	validation_1-logloss:0.66155
# [200]	validation_0-logloss:0.63300	validation_1-logloss:0.65743
# [291]	validation_0-logloss:0.62422	validation_1-logloss:0.65731
# 8(243), [0]	validation_0-logloss:0.69037	validation_1-logloss:0.69038
# [100]	validation_0-logloss:0.55963	validation_1-logloss:0.56104
# [200]	validation_0-logloss:0.52818	validation_1-logloss:0.53660
# [300]	validation_0-logloss:0.51364	validation_1-logloss:0.53106
# [400]	validation_0-logloss:0.50287	validation_1-logloss:0.52935
# [500]	validation_0-logloss:0.49377	validation_1-logloss:0.52861
# [558]	validation_0-logloss:0.48869	validation_1-logloss:0.52879
# 9(510), [0]	validation_0-logloss:0.69239	validation_1-logloss:0.69256
# [100]	validation_0-logloss:0.65143	validation_1-logloss:0.66243
# [200]	validation_0-logloss:0.63472	validation_1-logloss:0.65458
# [300]	validation_0-logloss:0.62347	validation_1-logloss:0.65152
# [400]	validation_0-logloss:0.61377	validation_1-logloss:0.64947
# [500]	validation_0-logloss:0.60504	validation_1-logloss:0.64882
# [600]	validation_0-logloss:0.59747	validation_1-logloss:0.64871
# [624]	validation_0-logloss:0.59551	validation_1-logloss:0.64872
# 10(575), [0]	validation_0-logloss:0.69173	validation_1-logloss:0.69187
# [100]	validation_0-logloss:0.62387	validation_1-logloss:0.63787
# [200]	validation_0-logloss:0.60411	validation_1-logloss:0.62974
# [300]	validation_0-logloss:0.59250	validation_1-logloss:0.62846
# [400]	validation_0-logloss:0.58308	validation_1-logloss:0.62799
# [444]	validation_0-logloss:0.57926	validation_1-logloss:0.62798
# 11(396), [0]	validation_0-logloss:0.68777	validation_1-logloss:0.68802
# [100]	validation_0-logloss:0.43615	validation_1-logloss:0.45616
# [200]	validation_0-logloss:0.38152	validation_1-logloss:0.41593
# [300]	validation_0-logloss:0.36382	validation_1-logloss:0.41041
# [388]	validation_0-logloss:0.35493	validation_1-logloss:0.41047
# 12(339), [0]	validation_0-logloss:0.69039	validation_1-logloss:0.69060
# [100]	validation_0-logloss:0.55836	validation_1-logloss:0.57746
# [200]	validation_0-logloss:0.52638	validation_1-logloss:0.55839
# [300]	validation_0-logloss:0.51216	validation_1-logloss:0.55531
# [400]	validation_0-logloss:0.50224	validation_1-logloss:0.55514
# [412]	validation_0-logloss:0.50107	validation_1-logloss:0.55502
# 13(363), [0]	validation_0-logloss:0.69075	validation_1-logloss:0.69085
# [100]	validation_0-logloss:0.57528	validation_1-logloss:0.58437
# [200]	validation_0-logloss:0.54569	validation_1-logloss:0.56453
# [300]	validation_0-logloss:0.53141	validation_1-logloss:0.56031
# [400]	validation_0-logloss:0.52058	validation_1-logloss:0.55943
# [500]	validation_0-logloss:0.51147	validation_1-logloss:0.55947
# [518]	validation_0-logloss:0.51006	validation_1-logloss:0.55948
# 14(470), [0]	validation_0-logloss:0.69231	validation_1-logloss:0.69244
# [100]	validation_0-logloss:0.64677	validation_1-logloss:0.66086
# [200]	validation_0-logloss:0.62749	validation_1-logloss:0.65403
# [300]	validation_0-logloss:0.61435	validation_1-logloss:0.65158
# [400]	validation_0-logloss:0.60355	validation_1-logloss:0.65061
# [500]	validation_0-logloss:0.59409	validation_1-logloss:0.64955
# [600]	validation_0-logloss:0.58511	validation_1-logloss:0.64896
# [700]	validation_0-logloss:0.57682	validation_1-logloss:0.64867
# [800]	validation_0-logloss:0.56907	validation_1-logloss:0.64833
# [900]	validation_0-logloss:0.56124	validation_1-logloss:0.64785
# [1000]	validation_0-logloss:0.55371	validation_1-logloss:0.64785
# [1022]	validation_0-logloss:0.55201	validation_1-logloss:0.64788
# 15(974), [0]	validation_0-logloss:0.69075	validation_1-logloss:0.69082
# [100]	validation_0-logloss:0.58052	validation_1-logloss:0.58824
# [200]	validation_0-logloss:0.55582	validation_1-logloss:0.57218
# [300]	validation_0-logloss:0.54480	validation_1-logloss:0.57010
# [374]	validation_0-logloss:0.53791	validation_1-logloss:0.57025
# 16(326), [0]	validation_0-logloss:0.69144	validation_1-logloss:0.69179
# [100]	validation_0-logloss:0.60991	validation_1-logloss:0.63471
# [200]	validation_0-logloss:0.58902	validation_1-logloss:0.62915
# [254]	validation_0-logloss:0.58257	validation_1-logloss:0.62944
# 17(206), [0]	validation_0-logloss:0.68493	validation_1-logloss:0.68503
# [100]	validation_0-logloss:0.29262	validation_1-logloss:0.30145
# [200]	validation_0-logloss:0.19577	validation_1-logloss:0.21306
# [300]	validation_0-logloss:0.16586	validation_1-logloss:0.19152
# [400]	validation_0-logloss:0.15281	validation_1-logloss:0.18689
# [500]	validation_0-logloss:0.14370	validation_1-logloss:0.18654
# [509]	validation_0-logloss:0.14301	validation_1-logloss:0.18652
# 18(461),
# #########################
# ### Fold 3
# #########################
# [0]	validation_0-logloss:0.69049	validation_1-logloss:0.69081
# [100]	validation_0-logloss:0.56063	validation_1-logloss:0.58690
# [200]	validation_0-logloss:0.52541	validation_1-logloss:0.56638
# [300]	validation_0-logloss:0.50768	validation_1-logloss:0.55972
# [400]	validation_0-logloss:0.49567	validation_1-logloss:0.55669
# [500]	validation_0-logloss:0.48580	validation_1-logloss:0.55502
# [600]	validation_0-logloss:0.47696	validation_1-logloss:0.55347
# [700]	validation_0-logloss:0.46873	validation_1-logloss:0.55246
# [800]	validation_0-logloss:0.46096	validation_1-logloss:0.55197
# [900]	validation_0-logloss:0.45417	validation_1-logloss:0.55147
# [1000]	validation_0-logloss:0.44718	validation_1-logloss:0.55095
# [1086]	validation_0-logloss:0.44162	validation_1-logloss:0.55088
# 1(1038), [0]	validation_0-logloss:0.68397	validation_1-logloss:0.68406
# [100]	validation_0-logloss:0.24213	validation_1-logloss:0.25006
# [200]	validation_0-logloss:0.12818	validation_1-logloss:0.14293
# [300]	validation_0-logloss:0.09167	validation_1-logloss:0.11341
# [400]	validation_0-logloss:0.07742	validation_1-logloss:0.10584
# [500]	validation_0-logloss:0.06930	validation_1-logloss:0.10362
# [600]	validation_0-logloss:0.06331	validation_1-logloss:0.10317
# [607]	validation_0-logloss:0.06297	validation_1-logloss:0.10314
# 2(559), [0]	validation_0-logloss:0.68561	validation_1-logloss:0.68576
# [100]	validation_0-logloss:0.32686	validation_1-logloss:0.33733
# [200]	validation_0-logloss:0.24156	validation_1-logloss:0.26083
# [300]	validation_0-logloss:0.21543	validation_1-logloss:0.24272
# [400]	validation_0-logloss:0.20362	validation_1-logloss:0.23866
# [500]	validation_0-logloss:0.19558	validation_1-logloss:0.23795
# [554]	validation_0-logloss:0.19183	validation_1-logloss:0.23805
# 3(505), [0]	validation_0-logloss:0.68887	validation_1-logloss:0.68903
# [100]	validation_0-logloss:0.48495	validation_1-logloss:0.50014
# [200]	validation_0-logloss:0.43644	validation_1-logloss:0.46250
# [300]	validation_0-logloss:0.41810	validation_1-logloss:0.45414
# [400]	validation_0-logloss:0.40632	validation_1-logloss:0.45190
# [500]	validation_0-logloss:0.39663	validation_1-logloss:0.45079
# [600]	validation_0-logloss:0.38822	validation_1-logloss:0.45048
# [700]	validation_0-logloss:0.37990	validation_1-logloss:0.45030
# [741]	validation_0-logloss:0.37707	validation_1-logloss:0.45038
# 4(693), [0]	validation_0-logloss:0.69220	validation_1-logloss:0.69243
# [100]	validation_0-logloss:0.64257	validation_1-logloss:0.66090
# [200]	validation_0-logloss:0.62407	validation_1-logloss:0.65530
# [300]	validation_0-logloss:0.61109	validation_1-logloss:0.65448
# [361]	validation_0-logloss:0.60445	validation_1-logloss:0.65476
# 5(312), [0]	validation_0-logloss:0.68945	validation_1-logloss:0.68985
# [100]	validation_0-logloss:0.51514	validation_1-logloss:0.54170
# [200]	validation_0-logloss:0.47451	validation_1-logloss:0.51829
# [300]	validation_0-logloss:0.45825	validation_1-logloss:0.51541
# [400]	validation_0-logloss:0.44738	validation_1-logloss:0.51537
# [442]	validation_0-logloss:0.44315	validation_1-logloss:0.51547
# 6(394), [0]	validation_0-logloss:0.69048	validation_1-logloss:0.69064
# [100]	validation_0-logloss:0.56431	validation_1-logloss:0.57651
# [200]	validation_0-logloss:0.53329	validation_1-logloss:0.55563
# [300]	validation_0-logloss:0.51897	validation_1-logloss:0.55119
# [400]	validation_0-logloss:0.50845	validation_1-logloss:0.54970
# [500]	validation_0-logloss:0.49960	validation_1-logloss:0.54915
# [600]	validation_0-logloss:0.49100	validation_1-logloss:0.54881
# [626]	validation_0-logloss:0.48895	validation_1-logloss:0.54889
# 7(577), [0]	validation_0-logloss:0.69228	validation_1-logloss:0.69243
# [100]	validation_0-logloss:0.64775	validation_1-logloss:0.66072
# [200]	validation_0-logloss:0.63227	validation_1-logloss:0.65635
# [300]	validation_0-logloss:0.62206	validation_1-logloss:0.65601
# [316]	validation_0-logloss:0.62062	validation_1-logloss:0.65598
# 8(268), [0]	validation_0-logloss:0.69026	validation_1-logloss:0.69058
# [100]	validation_0-logloss:0.55527	validation_1-logloss:0.57589
# [200]	validation_0-logloss:0.52331	validation_1-logloss:0.55675
# [300]	validation_0-logloss:0.50920	validation_1-logloss:0.55342
# [400]	validation_0-logloss:0.49836	validation_1-logloss:0.55186
# [500]	validation_0-logloss:0.48948	validation_1-logloss:0.55140
# [560]	validation_0-logloss:0.48449	validation_1-logloss:0.55147
# 9(512), [0]	validation_0-logloss:0.69233	validation_1-logloss:0.69260
# [100]	validation_0-logloss:0.64861	validation_1-logloss:0.67039
# [200]	validation_0-logloss:0.63136	validation_1-logloss:0.66757
# [300]	validation_0-logloss:0.61948	validation_1-logloss:0.66719
# [400]	validation_0-logloss:0.60980	validation_1-logloss:0.66696
# [467]	validation_0-logloss:0.60331	validation_1-logloss:0.66713
# 10(419), [0]	validation_0-logloss:0.69179	validation_1-logloss:0.69194
# [100]	validation_0-logloss:0.62420	validation_1-logloss:0.63720
# [200]	validation_0-logloss:0.60390	validation_1-logloss:0.62770
# [300]	validation_0-logloss:0.59190	validation_1-logloss:0.62606
# [357]	validation_0-logloss:0.58610	validation_1-logloss:0.62618
# 11(309), [0]	validation_0-logloss:0.68782	validation_1-logloss:0.68787
# [100]	validation_0-logloss:0.44030	validation_1-logloss:0.44627
# [200]	validation_0-logloss:0.38591	validation_1-logloss:0.39956
# [300]	validation_0-logloss:0.36799	validation_1-logloss:0.39070
# [400]	validation_0-logloss:0.35787	validation_1-logloss:0.38947
# [496]	validation_0-logloss:0.34971	validation_1-logloss:0.38935
# 12(447), [0]	validation_0-logloss:0.69047	validation_1-logloss:0.69042
# [100]	validation_0-logloss:0.56289	validation_1-logloss:0.56419
# [200]	validation_0-logloss:0.53168	validation_1-logloss:0.53967
# [300]	validation_0-logloss:0.51779	validation_1-logloss:0.53429
# [400]	validation_0-logloss:0.50817	validation_1-logloss:0.53292
# [500]	validation_0-logloss:0.49984	validation_1-logloss:0.53244
# [535]	validation_0-logloss:0.49712	validation_1-logloss:0.53239
# 13(486), [0]	validation_0-logloss:0.69072	validation_1-logloss:0.69093
# [100]	validation_0-logloss:0.57371	validation_1-logloss:0.58910
# [200]	validation_0-logloss:0.54425	validation_1-logloss:0.57153
# [300]	validation_0-logloss:0.53008	validation_1-logloss:0.56793
# [400]	validation_0-logloss:0.51963	validation_1-logloss:0.56672
# [500]	validation_0-logloss:0.51106	validation_1-logloss:0.56622
# [600]	validation_0-logloss:0.50280	validation_1-logloss:0.56558
# [700]	validation_0-logloss:0.49475	validation_1-logloss:0.56531
# [737]	validation_0-logloss:0.49185	validation_1-logloss:0.56527
# 14(689), [0]	validation_0-logloss:0.69234	validation_1-logloss:0.69248
# [100]	validation_0-logloss:0.64835	validation_1-logloss:0.65887
# [200]	validation_0-logloss:0.62979	validation_1-logloss:0.65085
# [300]	validation_0-logloss:0.61642	validation_1-logloss:0.64741
# [400]	validation_0-logloss:0.60572	validation_1-logloss:0.64588
# [500]	validation_0-logloss:0.59620	validation_1-logloss:0.64477
# [600]	validation_0-logloss:0.58749	validation_1-logloss:0.64404
# [700]	validation_0-logloss:0.57890	validation_1-logloss:0.64391
# [800]	validation_0-logloss:0.57106	validation_1-logloss:0.64347
# [893]	validation_0-logloss:0.56381	validation_1-logloss:0.64312
# 15(845), [0]	validation_0-logloss:0.69076	validation_1-logloss:0.69083
# [100]	validation_0-logloss:0.58103	validation_1-logloss:0.58717
# [200]	validation_0-logloss:0.55677	validation_1-logloss:0.57015
# [300]	validation_0-logloss:0.54580	validation_1-logloss:0.56727
# [400]	validation_0-logloss:0.53728	validation_1-logloss:0.56692
# [429]	validation_0-logloss:0.53491	validation_1-logloss:0.56702
# 16(380), [0]	validation_0-logloss:0.69153	validation_1-logloss:0.69168
# [100]	validation_0-logloss:0.61410	validation_1-logloss:0.62333
# [200]	validation_0-logloss:0.59335	validation_1-logloss:0.61265
# [300]	validation_0-logloss:0.58202	validation_1-logloss:0.61074
# [391]	validation_0-logloss:0.57364	validation_1-logloss:0.61083
# 17(343), [0]	validation_0-logloss:0.68496	validation_1-logloss:0.68501
# [100]	validation_0-logloss:0.29458	validation_1-logloss:0.29599
# [200]	validation_0-logloss:0.19855	validation_1-logloss:0.20382
# [300]	validation_0-logloss:0.16896	validation_1-logloss:0.18003
# [400]	validation_0-logloss:0.15592	validation_1-logloss:0.17381
# [500]	validation_0-logloss:0.14715	validation_1-logloss:0.17257
# [600]	validation_0-logloss:0.13924	validation_1-logloss:0.17266
# [632]	validation_0-logloss:0.13717	validation_1-logloss:0.17271
# 18(583),
# #########################
# ### Fold 4
# #########################
# [0]	validation_0-logloss:0.69047	validation_1-logloss:0.69060
# [100]	validation_0-logloss:0.56397	validation_1-logloss:0.57536
# [200]	validation_0-logloss:0.52947	validation_1-logloss:0.55116
# [300]	validation_0-logloss:0.51208	validation_1-logloss:0.54334
# [400]	validation_0-logloss:0.50003	validation_1-logloss:0.53909
# [500]	validation_0-logloss:0.49001	validation_1-logloss:0.53665
# [600]	validation_0-logloss:0.48114	validation_1-logloss:0.53460
# [700]	validation_0-logloss:0.47256	validation_1-logloss:0.53282
# [800]	validation_0-logloss:0.46494	validation_1-logloss:0.53164
# [900]	validation_0-logloss:0.45757	validation_1-logloss:0.53127
# [991]	validation_0-logloss:0.45125	validation_1-logloss:0.53105
# 1(943), [0]	validation_0-logloss:0.68398	validation_1-logloss:0.68401
# [100]	validation_0-logloss:0.24349	validation_1-logloss:0.24677
# [200]	validation_0-logloss:0.12974	validation_1-logloss:0.13710
# [300]	validation_0-logloss:0.09348	validation_1-logloss:0.10592
# [400]	validation_0-logloss:0.07930	validation_1-logloss:0.09719
# [500]	validation_0-logloss:0.07114	validation_1-logloss:0.09481
# [600]	validation_0-logloss:0.06464	validation_1-logloss:0.09417
# [633]	validation_0-logloss:0.06279	validation_1-logloss:0.09430
# 2(585), [0]	validation_0-logloss:0.68558	validation_1-logloss:0.68564
# [100]	validation_0-logloss:0.32795	validation_1-logloss:0.33339
# [200]	validation_0-logloss:0.24292	validation_1-logloss:0.25484
# [300]	validation_0-logloss:0.21674	validation_1-logloss:0.23587
# [400]	validation_0-logloss:0.20450	validation_1-logloss:0.23141
# [500]	validation_0-logloss:0.19607	validation_1-logloss:0.23044
# [568]	validation_0-logloss:0.19103	validation_1-logloss:0.23031
# 3(520), [0]	validation_0-logloss:0.68883	validation_1-logloss:0.68891
# [100]	validation_0-logloss:0.48616	validation_1-logloss:0.49778
# [200]	validation_0-logloss:0.43831	validation_1-logloss:0.45948
# [300]	validation_0-logloss:0.41955	validation_1-logloss:0.45076
# [400]	validation_0-logloss:0.40738	validation_1-logloss:0.44838
# [500]	validation_0-logloss:0.39737	validation_1-logloss:0.44753
# [600]	validation_0-logloss:0.38871	validation_1-logloss:0.44685
# [647]	validation_0-logloss:0.38479	validation_1-logloss:0.44695
# 4(598), [0]	validation_0-logloss:0.69226	validation_1-logloss:0.69228
# [100]	validation_0-logloss:0.64565	validation_1-logloss:0.65149
# [200]	validation_0-logloss:0.62791	validation_1-logloss:0.64310
# [300]	validation_0-logloss:0.61556	validation_1-logloss:0.64013
# [400]	validation_0-logloss:0.60521	validation_1-logloss:0.63871
# [500]	validation_0-logloss:0.59651	validation_1-logloss:0.63840
# [600]	validation_0-logloss:0.58819	validation_1-logloss:0.63822
# [700]	validation_0-logloss:0.57987	validation_1-logloss:0.63776
# [745]	validation_0-logloss:0.57642	validation_1-logloss:0.63795
# 5(697), [0]	validation_0-logloss:0.68954	validation_1-logloss:0.68959
# [100]	validation_0-logloss:0.52068	validation_1-logloss:0.52531
# [200]	validation_0-logloss:0.48165	validation_1-logloss:0.49353
# [300]	validation_0-logloss:0.46553	validation_1-logloss:0.48603
# [400]	validation_0-logloss:0.45471	validation_1-logloss:0.48409
# [500]	validation_0-logloss:0.44574	validation_1-logloss:0.48364
# [531]	validation_0-logloss:0.44315	validation_1-logloss:0.48365
# 6(483), [0]	validation_0-logloss:0.69053	validation_1-logloss:0.69058
# [100]	validation_0-logloss:0.56473	validation_1-logloss:0.57535
# [200]	validation_0-logloss:0.53401	validation_1-logloss:0.55462
# [300]	validation_0-logloss:0.51975	validation_1-logloss:0.54986
# [400]	validation_0-logloss:0.50966	validation_1-logloss:0.54819
# [500]	validation_0-logloss:0.50080	validation_1-logloss:0.54741
# [600]	validation_0-logloss:0.49247	validation_1-logloss:0.54673
# [700]	validation_0-logloss:0.48480	validation_1-logloss:0.54644
# [800]	validation_0-logloss:0.47692	validation_1-logloss:0.54578
# [900]	validation_0-logloss:0.46953	validation_1-logloss:0.54568
# [973]	validation_0-logloss:0.46431	validation_1-logloss:0.54571
# 7(924), [0]	validation_0-logloss:0.69223	validation_1-logloss:0.69245
# [100]	validation_0-logloss:0.64691	validation_1-logloss:0.66440
# [200]	validation_0-logloss:0.63157	validation_1-logloss:0.66198
# [267]	validation_0-logloss:0.62477	validation_1-logloss:0.66220
# 8(219), [0]	validation_0-logloss:0.69031	validation_1-logloss:0.69051
# [100]	validation_0-logloss:0.55548	validation_1-logloss:0.57357
# [200]	validation_0-logloss:0.52326	validation_1-logloss:0.55553
# [300]	validation_0-logloss:0.50836	validation_1-logloss:0.55316
# [368]	validation_0-logloss:0.50106	validation_1-logloss:0.55329
# 9(319), [0]	validation_0-logloss:0.69239	validation_1-logloss:0.69244
# [100]	validation_0-logloss:0.65166	validation_1-logloss:0.66160
# [200]	validation_0-logloss:0.63417	validation_1-logloss:0.65494
# [300]	validation_0-logloss:0.62244	validation_1-logloss:0.65325
# [400]	validation_0-logloss:0.61308	validation_1-logloss:0.65291
# [426]	validation_0-logloss:0.61078	validation_1-logloss:0.65300
# 10(377), [0]	validation_0-logloss:0.69178	validation_1-logloss:0.69191
# [100]	validation_0-logloss:0.62553	validation_1-logloss:0.63398
# [200]	validation_0-logloss:0.60582	validation_1-logloss:0.62427
# [300]	validation_0-logloss:0.59415	validation_1-logloss:0.62199
# [400]	validation_0-logloss:0.58433	validation_1-logloss:0.62156
# [436]	validation_0-logloss:0.58104	validation_1-logloss:0.62154
# 11(388), [0]	validation_0-logloss:0.68778	validation_1-logloss:0.68787
# [100]	validation_0-logloss:0.43989	validation_1-logloss:0.44658
# [200]	validation_0-logloss:0.38605	validation_1-logloss:0.40061
# [300]	validation_0-logloss:0.36866	validation_1-logloss:0.39183
# [400]	validation_0-logloss:0.35830	validation_1-logloss:0.39039
# [488]	validation_0-logloss:0.35131	validation_1-logloss:0.39046
# 12(439), [0]	validation_0-logloss:0.69042	validation_1-logloss:0.69052
# [100]	validation_0-logloss:0.55986	validation_1-logloss:0.57157
# [200]	validation_0-logloss:0.52765	validation_1-logloss:0.55140
# [300]	validation_0-logloss:0.51349	validation_1-logloss:0.54810
# [400]	validation_0-logloss:0.50330	validation_1-logloss:0.54769
# [424]	validation_0-logloss:0.50124	validation_1-logloss:0.54772
# 13(375), [0]	validation_0-logloss:0.69073	validation_1-logloss:0.69074
# [100]	validation_0-logloss:0.57633	validation_1-logloss:0.58103
# [200]	validation_0-logloss:0.54738	validation_1-logloss:0.56012
# [300]	validation_0-logloss:0.53347	validation_1-logloss:0.55595
# [400]	validation_0-logloss:0.52330	validation_1-logloss:0.55459
# [473]	validation_0-logloss:0.51642	validation_1-logloss:0.55450
# 14(424), [0]	validation_0-logloss:0.69235	validation_1-logloss:0.69253
# [100]	validation_0-logloss:0.64678	validation_1-logloss:0.66174
# [200]	validation_0-logloss:0.62747	validation_1-logloss:0.65584
# [300]	validation_0-logloss:0.61467	validation_1-logloss:0.65421
# [400]	validation_0-logloss:0.60428	validation_1-logloss:0.65341
# [500]	validation_0-logloss:0.59494	validation_1-logloss:0.65301
# [576]	validation_0-logloss:0.58820	validation_1-logloss:0.65294
# 15(527), [0]	validation_0-logloss:0.69069	validation_1-logloss:0.69098
# [100]	validation_0-logloss:0.57729	validation_1-logloss:0.59664
# [200]	validation_0-logloss:0.55183	validation_1-logloss:0.58539
# [300]	validation_0-logloss:0.54016	validation_1-logloss:0.58492
# [344]	validation_0-logloss:0.53605	validation_1-logloss:0.58538
# 16(295), [0]	validation_0-logloss:0.69151	validation_1-logloss:0.69154
# [100]	validation_0-logloss:0.61303	validation_1-logloss:0.62355
# [200]	validation_0-logloss:0.59213	validation_1-logloss:0.61382
# [300]	validation_0-logloss:0.58059	validation_1-logloss:0.61311
# [308]	validation_0-logloss:0.57987	validation_1-logloss:0.61314
# 17(259), [0]	validation_0-logloss:0.68497	validation_1-logloss:0.68500
# [100]	validation_0-logloss:0.29548	validation_1-logloss:0.29571
# [200]	validation_0-logloss:0.19988	validation_1-logloss:0.20172
# [300]	validation_0-logloss:0.17043	validation_1-logloss:0.17666
# [400]	validation_0-logloss:0.15729	validation_1-logloss:0.16981
# [500]	validation_0-logloss:0.14873	validation_1-logloss:0.16815
# [600]	validation_0-logloss:0.14098	validation_1-logloss:0.16744
# [699]	validation_0-logloss:0.13460	validation_1-logloss:0.16748
# 18(650),
# #########################
# ### Fold 5
# #########################
# [0]	validation_0-logloss:0.69049	validation_1-logloss:0.69076
# [100]	validation_0-logloss:0.56248	validation_1-logloss:0.58137
# [200]	validation_0-logloss:0.52744	validation_1-logloss:0.55880
# [300]	validation_0-logloss:0.50978	validation_1-logloss:0.55175
# [400]	validation_0-logloss:0.49759	validation_1-logloss:0.54885
# [500]	validation_0-logloss:0.48788	validation_1-logloss:0.54729
# [600]	validation_0-logloss:0.47932	validation_1-logloss:0.54625
# [700]	validation_0-logloss:0.47124	validation_1-logloss:0.54527
# [800]	validation_0-logloss:0.46404	validation_1-logloss:0.54475
# [900]	validation_0-logloss:0.45738	validation_1-logloss:0.54420
# [1000]	validation_0-logloss:0.45082	validation_1-logloss:0.54389
# [1088]	validation_0-logloss:0.44546	validation_1-logloss:0.54367
# 1(1039), [0]	validation_0-logloss:0.68403	validation_1-logloss:0.68402
# [100]	validation_0-logloss:0.24469	validation_1-logloss:0.24465
# [200]	validation_0-logloss:0.13113	validation_1-logloss:0.13324
# [300]	validation_0-logloss:0.09463	validation_1-logloss:0.10091
# [400]	validation_0-logloss:0.08027	validation_1-logloss:0.09208
# [500]	validation_0-logloss:0.07209	validation_1-logloss:0.09006
# [600]	validation_0-logloss:0.06587	validation_1-logloss:0.08991
# [671]	validation_0-logloss:0.06184	validation_1-logloss:0.09000
# 2(622), [0]	validation_0-logloss:0.68557	validation_1-logloss:0.68570
# [100]	validation_0-logloss:0.32675	validation_1-logloss:0.33554
# [200]	validation_0-logloss:0.24130	validation_1-logloss:0.25796
# [300]	validation_0-logloss:0.21528	validation_1-logloss:0.23971
# [400]	validation_0-logloss:0.20374	validation_1-logloss:0.23524
# [500]	validation_0-logloss:0.19558	validation_1-logloss:0.23432
# [600]	validation_0-logloss:0.18858	validation_1-logloss:0.23412
# [635]	validation_0-logloss:0.18613	validation_1-logloss:0.23413
# 3(586), [0]	validation_0-logloss:0.68883	validation_1-logloss:0.68897
# [100]	validation_0-logloss:0.48510	validation_1-logloss:0.49862
# [200]	validation_0-logloss:0.43577	validation_1-logloss:0.46250
# [300]	validation_0-logloss:0.41694	validation_1-logloss:0.45564
# [400]	validation_0-logloss:0.40516	validation_1-logloss:0.45485
# [476]	validation_0-logloss:0.39781	validation_1-logloss:0.45474
# 4(427), [0]	validation_0-logloss:0.69219	validation_1-logloss:0.69244
# [100]	validation_0-logloss:0.64164	validation_1-logloss:0.66303
# [200]	validation_0-logloss:0.62347	validation_1-logloss:0.65947
# [300]	validation_0-logloss:0.61097	validation_1-logloss:0.65836
# [400]	validation_0-logloss:0.60130	validation_1-logloss:0.65790
# [450]	validation_0-logloss:0.59707	validation_1-logloss:0.65804
# 5(401), [0]	validation_0-logloss:0.68954	validation_1-logloss:0.68951
# [100]	validation_0-logloss:0.52206	validation_1-logloss:0.52213
# [200]	validation_0-logloss:0.48291	validation_1-logloss:0.48926
# [300]	validation_0-logloss:0.46679	validation_1-logloss:0.48145
# [400]	validation_0-logloss:0.45541	validation_1-logloss:0.47905
# [500]	validation_0-logloss:0.44626	validation_1-logloss:0.47811
# [600]	validation_0-logloss:0.43809	validation_1-logloss:0.47766
# [700]	validation_0-logloss:0.43055	validation_1-logloss:0.47754
# [709]	validation_0-logloss:0.42987	validation_1-logloss:0.47747
# 6(661), [0]	validation_0-logloss:0.69051	validation_1-logloss:0.69062
# [100]	validation_0-logloss:0.56408	validation_1-logloss:0.57565
# [200]	validation_0-logloss:0.53294	validation_1-logloss:0.55562
# [300]	validation_0-logloss:0.51844	validation_1-logloss:0.55164
# [400]	validation_0-logloss:0.50798	validation_1-logloss:0.55030
# [500]	validation_0-logloss:0.49856	validation_1-logloss:0.54963
# [600]	validation_0-logloss:0.49056	validation_1-logloss:0.54925
# [603]	validation_0-logloss:0.49031	validation_1-logloss:0.54929
# 7(555), [0]	validation_0-logloss:0.69228	validation_1-logloss:0.69243
# [100]	validation_0-logloss:0.64897	validation_1-logloss:0.65903
# [200]	validation_0-logloss:0.63333	validation_1-logloss:0.65371
# [300]	validation_0-logloss:0.62321	validation_1-logloss:0.65301
# [361]	validation_0-logloss:0.61787	validation_1-logloss:0.65329
# 8(313), [0]	validation_0-logloss:0.69038	validation_1-logloss:0.69036
# [100]	validation_0-logloss:0.56027	validation_1-logloss:0.56097
# [200]	validation_0-logloss:0.52913	validation_1-logloss:0.53559
# [300]	validation_0-logloss:0.51498	validation_1-logloss:0.52943
# [400]	validation_0-logloss:0.50478	validation_1-logloss:0.52756
# [500]	validation_0-logloss:0.49586	validation_1-logloss:0.52732
# [522]	validation_0-logloss:0.49405	validation_1-logloss:0.52723
# 9(474), [0]	validation_0-logloss:0.69237	validation_1-logloss:0.69254
# [100]	validation_0-logloss:0.64956	validation_1-logloss:0.66661
# [200]	validation_0-logloss:0.63195	validation_1-logloss:0.66227
# [300]	validation_0-logloss:0.61955	validation_1-logloss:0.66161
# [355]	validation_0-logloss:0.61362	validation_1-logloss:0.66164
# 10(306), [0]	validation_0-logloss:0.69174	validation_1-logloss:0.69195
# [100]	validation_0-logloss:0.62336	validation_1-logloss:0.63924
# [200]	validation_0-logloss:0.60317	validation_1-logloss:0.63163
# [300]	validation_0-logloss:0.59102	validation_1-logloss:0.63079
# [327]	validation_0-logloss:0.58828	validation_1-logloss:0.63089
# 11(279), [0]	validation_0-logloss:0.68784	validation_1-logloss:0.68783
# [100]	validation_0-logloss:0.44095	validation_1-logloss:0.44412
# [200]	validation_0-logloss:0.38716	validation_1-logloss:0.39654
# [300]	validation_0-logloss:0.36979	validation_1-logloss:0.38683
# [400]	validation_0-logloss:0.35960	validation_1-logloss:0.38489
# [500]	validation_0-logloss:0.35141	validation_1-logloss:0.38432
# [581]	validation_0-logloss:0.34488	validation_1-logloss:0.38441
# 12(533), [0]	validation_0-logloss:0.69042	validation_1-logloss:0.69057
# [100]	validation_0-logloss:0.55884	validation_1-logloss:0.57495
# [200]	validation_0-logloss:0.52618	validation_1-logloss:0.55521
# [300]	validation_0-logloss:0.51199	validation_1-logloss:0.55240
# [400]	validation_0-logloss:0.50217	validation_1-logloss:0.55216
# [411]	validation_0-logloss:0.50120	validation_1-logloss:0.55231
# 13(362), [0]	validation_0-logloss:0.69065	validation_1-logloss:0.69090
# [100]	validation_0-logloss:0.57280	validation_1-logloss:0.59109
# [200]	validation_0-logloss:0.54281	validation_1-logloss:0.57532
# [300]	validation_0-logloss:0.52868	validation_1-logloss:0.57298
# [400]	validation_0-logloss:0.51821	validation_1-logloss:0.57280
# [443]	validation_0-logloss:0.51404	validation_1-logloss:0.57296
# 14(394), [0]	validation_0-logloss:0.69232	validation_1-logloss:0.69238
# [100]	validation_0-logloss:0.64880	validation_1-logloss:0.65765
# [200]	validation_0-logloss:0.63032	validation_1-logloss:0.64855
# [300]	validation_0-logloss:0.61760	validation_1-logloss:0.64523
# [400]	validation_0-logloss:0.60695	validation_1-logloss:0.64365
# [500]	validation_0-logloss:0.59730	validation_1-logloss:0.64272
# [600]	validation_0-logloss:0.58819	validation_1-logloss:0.64228
# [700]	validation_0-logloss:0.57979	validation_1-logloss:0.64180
# [800]	validation_0-logloss:0.57185	validation_1-logloss:0.64165
# [825]	validation_0-logloss:0.56983	validation_1-logloss:0.64164
# 15(777), [0]	validation_0-logloss:0.69071	validation_1-logloss:0.69082
# [100]	validation_0-logloss:0.57933	validation_1-logloss:0.59173
# [200]	validation_0-logloss:0.55417	validation_1-logloss:0.57738
# [300]	validation_0-logloss:0.54284	validation_1-logloss:0.57581
# [348]	validation_0-logloss:0.53853	validation_1-logloss:0.57601
# 16(299), [0]	validation_0-logloss:0.69152	validation_1-logloss:0.69155
# [100]	validation_0-logloss:0.61418	validation_1-logloss:0.62105
# [200]	validation_0-logloss:0.59367	validation_1-logloss:0.60870
# [300]	validation_0-logloss:0.58208	validation_1-logloss:0.60670
# [386]	validation_0-logloss:0.57383	validation_1-logloss:0.60659
# 17(337), [0]	validation_0-logloss:0.68485	validation_1-logloss:0.68511
# [100]	validation_0-logloss:0.28949	validation_1-logloss:0.30834
# [200]	validation_0-logloss:0.19153	validation_1-logloss:0.22554
# [300]	validation_0-logloss:0.16109	validation_1-logloss:0.20832
# [400]	validation_0-logloss:0.14770	validation_1-logloss:0.20675
# [425]	validation_0-logloss:0.14533	validation_1-logloss:0.20710
# 18(376),

# %%
def plot_feature_importance(importance,names,model_type):

    #Create arrays from feature importance and feature names
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    #Create a DataFrame using a Dictionary
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)

    #Sort the DataFrame in order decreasing feature importance
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_df = fi_df.tail(20)
    #Define size of bar plot
    plt.figure(figsize=(20,10))
    #Plot Searborn bar chart
    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
    #Add chart labels
    plt.title(model_type + 'FEATURE IMPORTANCE')
    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')

# %%
feat_imp = {}

# %%
for k, v in models.items():
    for x, y in zip(v.feature_importances_, v.feature_names_in_):
        if y not in feat_imp:
            feat_imp[y] = x
        else:
            feat_imp[y]+=x

# %%
plot_feature_importance(list(feat_imp.values()),list(feat_imp.keys()),'')

# %%
# PUT TRUE LABELS INTO DATAFRAME WITH 18 COLUMNS
true = oof.copy()
for k in range(18):
    # GET TRUE LABELS
    tmp = train_labels.loc[train_labels.question == k+1].set_index('session').loc[ALL_USERS]
    true[k] = tmp.correct.values

# %%
# FIND BEST THRESHOLD TO CONVERT PROBS INTO 1s AND 0s
scores = []; thresholds = []
best_score = 0; best_threshold = 0

for threshold in np.arange(0.4,0.81,0.01):
    print(f'{threshold:.02f}, ',end='')
    preds = (oof.values.reshape((-1))>threshold).astype('int')
    m = f1_score(true.values.reshape((-1)), preds, average='macro')
    scores.append(m)
    thresholds.append(threshold)
    if m>best_score:
        best_score = m
        best_threshold = threshold
# Out:
# 0.40, 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.50, 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.60, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.70, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.80,

# %%
import matplotlib.pyplot as plt

# PLOT THRESHOLD VS. F1_SCORE
plt.figure(figsize=(20,5))
plt.plot(thresholds,scores,'-o',color='blue')
plt.scatter([best_threshold], [best_score], color='blue', s=300, alpha=1)
plt.xlabel('Threshold',size=14)
plt.ylabel('Validation F1 Score',size=14)
plt.title(f'Threshold vs. F1_Score with Best F1_Score = {best_score:.4f} at Best Threshold = {best_threshold:.3}',size=18)
plt.show()

# %%
print('When using optimal threshold...')
for k in range(18):
        
    # COMPUTE F1 SCORE PER QUESTION
    m = f1_score(true[k].values, (oof[k].values>best_threshold).astype('int'), average='macro')
    print(f'Q{k}: F1 =',m)
    
# COMPUTE F1 SCORE OVERALL
m = f1_score(true.values.reshape((-1)), (oof.values.reshape((-1))>best_threshold).astype('int'), average='macro')
print('==> Overall F1 =',m)
# Out:
# When using optimal threshold...
# Q0: F1 = 0.6336784412654983
# Q1: F1 = 0.49864232092097566
# Q2: F1 = 0.49713040810591064
# Q3: F1 = 0.6111780894345156
# Q4: F1 = 0.5957005989189499
# Q5: F1 = 0.6021439497267769
# Q6: F1 = 0.5904687465475009
# Q7: F1 = 0.5428429554992769
# Q8: F1 = 0.5973469582133524
# Q9: F1 = 0.5293631038860194
# Q10: F1 = 0.5940978401784613
# Q11: F1 = 0.4976400221912755
# Q12: F1 = 0.4400063248246655
# Q13: F1 = 0.6024390552814518
# Q14: F1 = 0.5280612156127361
# Q15: F1 = 0.4489079222686408
# Q16: F1 = 0.5207469918597405
# Q17: F1 = 0.4956654786637034
# ==> Overall F1 = 0.6799073584890949

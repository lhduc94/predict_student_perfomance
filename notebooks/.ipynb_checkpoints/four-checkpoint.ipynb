# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc
from collections import Counter
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GroupKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, classification_report
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %%
class Config:
    TRAIN_PATH = '../inputs/train.csv'
    TEST_PATH = '../inputs/test.csv'
    TRAIN_LABELS = '../inputs/train_labels.csv'
    SAMPLE_SUBMISSION = '../inputs/sample_submission.csv'

# %%
def q2l(x):
    if x <= 3:
        return '0-4'
    if x <= 13:
        return '5-12'
    return '13-22'

# %%
event_features =  ['checkpoint_click','cutscene_click', 'person_click', 'navigate_click',
                   'observation_click', 'notification_click', 'object_click',
                   'object_hover', 'map_hover', 'map_click', 'notebook_click']
room_features = ['historicalsociety',
          'kohlcenter',
          'capitol_0',
          'humanecology',
          'drycleaner',
          'library',
          'capitol_1',
          'wildlife',
          'flaghouse','capitol_2']
num_features = [ 
        'page', 
        'room_coor_x', 
        'room_coor_y', 
        'screen_coor_x', 
        'screen_coor_y', 
        'hover_duration']
def groupby_apply(g):
    res = {}
    for col in num_features:
        res[f'{col}_mean'] = np.mean(g[col])
        res[f'{col}_max'] = np.max(g[col])
        res[f'{col}_min'] = np.min(g[col])
        res[f'{col}_std'] = np.std(g[col])
    elasped_time = g['elapsed_time'].values/1000
    level = g['level'].values
    res['duration'] = elasped_time.max() - elasped_time.min()
    for i in range(0,23):
        t = elasped_time[level==i]
        if len(t) > 0 :
            res[f'duration_level_{i}'] = t.max()-t.min()
        else:
            res[f'duration_level_{i}'] = 0
    res['text_fqid_null'] = pd.isnull(g['text_fqid']).sum()
    event_name_dict = Counter(g['event_name'].values)
    event_sequence = g['event_name'].values
    room_event_dict = Counter(g['room_event'].values)
    room_sequence = g['main_room'].values
    for col in event_features:
        res[f'{col}_sum'] = event_name_dict.get(col, 0)
    
    room_dict = Counter(g['main_room'].values)
    for col in room_features:
        res[f'{col}_sum'] = room_dict.get(col, 0)
    for col in num_features:
        res[f'{col}_mean'] = np.mean(g[col])
        res[f'{col}_max'] = np.max(g[col])
        res[f'{col}_min'] = np.min(g[col])
        res[f'{col}_std'] = np.std(g[col])
    elapsed_time_diff_all = np.diff(elasped_time)
    res['elapsed_time_diff_mean'] = np.mean(elapsed_time_diff_all)
    res['elapsed_time_diff_std'] = np.std(elapsed_time_diff_all)
    res['elapsed_time_diff_max'] = np.max(elapsed_time_diff_all)
    res['elapsed_time_diff_min'] = np.min(elapsed_time_diff_all)
    res['elapsed_time_diff_positive'] = len(elapsed_time_diff_all[elapsed_time_diff_all>0])
    
    for col in event_features:
        elapsed_time_diff_event = elapsed_time_diff_all[event_sequence[1:]==col]
        elapsed_time_diff_event = elapsed_time_diff_event if len(elapsed_time_diff_event) > 0 else [0]
        res[f'elapsed_time_diff_{col}_mean'] = np.mean(elapsed_time_diff_event)
        res[f'elapsed_time_diff_{col}_max'] = np.max(elapsed_time_diff_event)
        res[f'elapsed_time_diff_{col}_min'] = np.min(elapsed_time_diff_event)
    return pd.Series(res)

# %%
def feature_engineering(df, meta):
    df['main_room'] = df['room_fqid'].str.split('.').str[1]
    df['room_event'] =  df['event_name']+'_' + df['main_room']
    X = df.groupby(['session','level_group']).apply(groupby_apply).reset_index()
    X = meta.merge(X,how='left', on=['session','level_group'])
    for i in range(1,19):
        X[f'q{i}'] = X['question'] == i
    return X

# %%
train_df = pd.read_csv(Config.TRAIN_PATH, usecols=lambda x: x not in ['fullscreen','hq','music'])
train_df['main_room'] = train_df['room_fqid'].str.split('.').str[1]
train_df['room_event'] =  train_df['event_name']+'_' + train_df['main_room']
train_labels = pd.read_csv(Config.TRAIN_LABELS)
train_df.rename(columns={'session_id':'session'},inplace=True)
train_labels['question'] = train_labels['session_id'].str.split('q').str[-1].astype('int')
train_labels['session'] = train_labels['session_id'].str.split('_').str[0].astype('int64')
train_labels['level_group'] = train_labels['question'].apply(lambda x: q2l(x))

# %%
df1 = train_df.loc[train_df.level_group=='0-4']
X1 = df1.groupby(['session']).apply(groupby_apply).reset_index()
X1['level_group'] = '0-4'
del df1
gc.collect()
# Out:
# 17

# %%
df2 = train_df.loc[(train_df.level_group=='0-4')|(train_df.level_group=='5-12')]
X2 = df2.groupby(['session']).apply(groupby_apply).reset_index()
X2['level_group'] = '5-12'
del df2
gc.collect()
# Out:
# 0

# %%
X3 = train_df.groupby(['session']).apply(groupby_apply).reset_index()
X3['level_group'] = '13-22'
gc.collect()
# Out:
# 0

# %%
X = pd.concat([X1,X2,X3])
X = train_labels.merge(X,how='left', on=['session','level_group'])
for i in range(1,19):
    X[f'q{i}'] = X['question'] == i

# %%
FEATURES = X.columns[5:]
len(FEATURES)
# Out:
# 126

# %%
n_splits=5
gkf = GroupKFold(n_splits=n_splits)
oof = np.zeros(X.shape[0])
models = {}

# COMPUTE CV SCORE WITH 5 GROUP K FOLD
for i, (train_index, valid_index) in enumerate(gkf.split(X, groups=X['session'])):
    print('#'*25)
    print('### Fold',i+1)
    print('#'*25)

    xgb_params = {
        'objective' : 'binary:logistic',
        'eval_metric':'logloss',
        'learning_rate': 0.01,
        'max_depth': 5,
        'n_estimators': 3000,
        'early_stopping_rounds': 50,
        'subsample':0.8,
        'colsample_bytree': 0.8,
        'tree_method': 'gpu_hist',
        'seed':42,
        'use_label_encoder' : False}

    X_train = X.iloc[train_index][FEATURES]
    X_valid = X.iloc[valid_index][FEATURES]
    y_train = X.iloc[train_index]['correct'].values
    y_valid = X.iloc[valid_index]['correct'].values
        # TRAIN MODEL
    clf =  XGBClassifier(**xgb_params)
    clf.fit(X_train.astype('float32'), y_train,
            eval_set=[(X_train.astype('float32'), y_train), (X_valid.astype('float32'),y_valid)],
            verbose=100)
    print(f'({clf.best_ntree_limit}), ',end='')

        # SAVE MODEL, PREDICT VALID OOF
    models[i] = clf
    oof[valid_index] = clf.predict_proba(X_valid)[:,1]

    print()
# Out:
# #########################
# ### Fold 1
# #########################
# [0]	validation_0-logloss:0.69033	validation_1-logloss:0.69033
# [100]	validation_0-logloss:0.55722	validation_1-logloss:0.55668
# [200]	validation_0-logloss:0.52314	validation_1-logloss:0.52242
# [300]	validation_0-logloss:0.50874	validation_1-logloss:0.50853
# [400]	validation_0-logloss:0.50031	validation_1-logloss:0.50108
# [500]	validation_0-logloss:0.49454	validation_1-logloss:0.49665
# [600]	validation_0-logloss:0.49010	validation_1-logloss:0.49372
# [700]	validation_0-logloss:0.48646	validation_1-logloss:0.49176
# [800]	validation_0-logloss:0.48340	validation_1-logloss:0.49043
# [900]	validation_0-logloss:0.48062	validation_1-logloss:0.48943
# [1000]	validation_0-logloss:0.47812	validation_1-logloss:0.48871
# [1100]	validation_0-logloss:0.47581	validation_1-logloss:0.48814
# [1200]	validation_0-logloss:0.47371	validation_1-logloss:0.48767
# [1300]	validation_0-logloss:0.47174	validation_1-logloss:0.48732
# [1400]	validation_0-logloss:0.46976	validation_1-logloss:0.48697
# [1500]	validation_0-logloss:0.46794	validation_1-logloss:0.48675
# [1600]	validation_0-logloss:0.46623	validation_1-logloss:0.48655
# [1700]	validation_0-logloss:0.46448	validation_1-logloss:0.48637
# [1800]	validation_0-logloss:0.46280	validation_1-logloss:0.48620
# [1900]	validation_0-logloss:0.46122	validation_1-logloss:0.48605
# [2000]	validation_0-logloss:0.45965	validation_1-logloss:0.48589
# [2100]	validation_0-logloss:0.45819	validation_1-logloss:0.48577
# [2200]	validation_0-logloss:0.45668	validation_1-logloss:0.48562
# [2300]	validation_0-logloss:0.45529	validation_1-logloss:0.48553
# [2400]	validation_0-logloss:0.45391	validation_1-logloss:0.48546
# [2457]	validation_0-logloss:0.45309	validation_1-logloss:0.48544
# (2409),
# #########################
# ### Fold 2
# #########################
# [0]	validation_0-logloss:0.69033	validation_1-logloss:0.69032
# [100]	validation_0-logloss:0.55680	validation_1-logloss:0.55696
# [200]	validation_0-logloss:0.52232	validation_1-logloss:0.52360
# [300]	validation_0-logloss:0.50789	validation_1-logloss:0.51076
# [400]	validation_0-logloss:0.49941	validation_1-logloss:0.50399
# [500]	validation_0-logloss:0.49347	validation_1-logloss:0.49996
# [600]	validation_0-logloss:0.48906	validation_1-logloss:0.49746
# [700]	validation_0-logloss:0.48545	validation_1-logloss:0.49583
# [800]	validation_0-logloss:0.48232	validation_1-logloss:0.49465
# [900]	validation_0-logloss:0.47955	validation_1-logloss:0.49384
# [1000]	validation_0-logloss:0.47713	validation_1-logloss:0.49320
# [1100]	validation_0-logloss:0.47486	validation_1-logloss:0.49275
# [1200]	validation_0-logloss:0.47269	validation_1-logloss:0.49227
# [1300]	validation_0-logloss:0.47070	validation_1-logloss:0.49192
# [1400]	validation_0-logloss:0.46885	validation_1-logloss:0.49170
# [1500]	validation_0-logloss:0.46707	validation_1-logloss:0.49145
# [1600]	validation_0-logloss:0.46533	validation_1-logloss:0.49124
# [1700]	validation_0-logloss:0.46357	validation_1-logloss:0.49106
# [1800]	validation_0-logloss:0.46189	validation_1-logloss:0.49089
# [1900]	validation_0-logloss:0.46031	validation_1-logloss:0.49072
# [2000]	validation_0-logloss:0.45881	validation_1-logloss:0.49060
# [2100]	validation_0-logloss:0.45730	validation_1-logloss:0.49046
# [2200]	validation_0-logloss:0.45580	validation_1-logloss:0.49038
# [2300]	validation_0-logloss:0.45441	validation_1-logloss:0.49027
# [2400]	validation_0-logloss:0.45298	validation_1-logloss:0.49019
# [2500]	validation_0-logloss:0.45164	validation_1-logloss:0.49017
# [2600]	validation_0-logloss:0.45027	validation_1-logloss:0.49006
# [2700]	validation_0-logloss:0.44894	validation_1-logloss:0.49000
# [2800]	validation_0-logloss:0.44770	validation_1-logloss:0.48993
# [2858]	validation_0-logloss:0.44693	validation_1-logloss:0.48992
# (2810),
# #########################
# ### Fold 3
# #########################
# [0]	validation_0-logloss:0.69034	validation_1-logloss:0.69040
# [100]	validation_0-logloss:0.55598	validation_1-logloss:0.55961
# [200]	validation_0-logloss:0.52117	validation_1-logloss:0.52707
# [300]	validation_0-logloss:0.50656	validation_1-logloss:0.51450
# [400]	validation_0-logloss:0.49813	validation_1-logloss:0.50802
# [500]	validation_0-logloss:0.49227	validation_1-logloss:0.50412
# [600]	validation_0-logloss:0.48785	validation_1-logloss:0.50165
# [700]	validation_0-logloss:0.48428	validation_1-logloss:0.49988
# [800]	validation_0-logloss:0.48124	validation_1-logloss:0.49876
# [900]	validation_0-logloss:0.47854	validation_1-logloss:0.49784
# [1000]	validation_0-logloss:0.47607	validation_1-logloss:0.49717
# [1100]	validation_0-logloss:0.47385	validation_1-logloss:0.49664
# [1200]	validation_0-logloss:0.47173	validation_1-logloss:0.49621
# [1300]	validation_0-logloss:0.46977	validation_1-logloss:0.49587
# [1400]	validation_0-logloss:0.46784	validation_1-logloss:0.49556
# [1500]	validation_0-logloss:0.46608	validation_1-logloss:0.49532
# [1600]	validation_0-logloss:0.46427	validation_1-logloss:0.49511
# [1700]	validation_0-logloss:0.46256	validation_1-logloss:0.49495
# [1800]	validation_0-logloss:0.46092	validation_1-logloss:0.49481
# [1900]	validation_0-logloss:0.45934	validation_1-logloss:0.49466
# [2000]	validation_0-logloss:0.45780	validation_1-logloss:0.49452
# [2100]	validation_0-logloss:0.45628	validation_1-logloss:0.49442
# [2200]	validation_0-logloss:0.45488	validation_1-logloss:0.49430
# [2300]	validation_0-logloss:0.45340	validation_1-logloss:0.49415
# [2400]	validation_0-logloss:0.45201	validation_1-logloss:0.49410
# [2500]	validation_0-logloss:0.45065	validation_1-logloss:0.49398
# [2600]	validation_0-logloss:0.44929	validation_1-logloss:0.49394
# [2700]	validation_0-logloss:0.44797	validation_1-logloss:0.49385
# [2800]	validation_0-logloss:0.44667	validation_1-logloss:0.49381
# [2866]	validation_0-logloss:0.44584	validation_1-logloss:0.49381
# (2818),
# #########################
# ### Fold 4
# #########################
# [0]	validation_0-logloss:0.69034	validation_1-logloss:0.69037
# [100]	validation_0-logloss:0.55633	validation_1-logloss:0.55822
# [200]	validation_0-logloss:0.52187	validation_1-logloss:0.52501
# [300]	validation_0-logloss:0.50731	validation_1-logloss:0.51167
# [400]	validation_0-logloss:0.49901	validation_1-logloss:0.50487
# [500]	validation_0-logloss:0.49317	validation_1-logloss:0.50076
# [600]	validation_0-logloss:0.48876	validation_1-logloss:0.49817
# [700]	validation_0-logloss:0.48511	validation_1-logloss:0.49642
# [800]	validation_0-logloss:0.48202	validation_1-logloss:0.49523
# [900]	validation_0-logloss:0.47925	validation_1-logloss:0.49439
# [1000]	validation_0-logloss:0.47674	validation_1-logloss:0.49376
# [1100]	validation_0-logloss:0.47445	validation_1-logloss:0.49325
# [1200]	validation_0-logloss:0.47227	validation_1-logloss:0.49286
# [1300]	validation_0-logloss:0.47022	validation_1-logloss:0.49256
# [1400]	validation_0-logloss:0.46835	validation_1-logloss:0.49227
# [1500]	validation_0-logloss:0.46659	validation_1-logloss:0.49209
# [1600]	validation_0-logloss:0.46479	validation_1-logloss:0.49194
# [1700]	validation_0-logloss:0.46312	validation_1-logloss:0.49181
# [1800]	validation_0-logloss:0.46150	validation_1-logloss:0.49165
# [1900]	validation_0-logloss:0.45989	validation_1-logloss:0.49154
# [2000]	validation_0-logloss:0.45838	validation_1-logloss:0.49145
# [2100]	validation_0-logloss:0.45684	validation_1-logloss:0.49137
# [2200]	validation_0-logloss:0.45537	validation_1-logloss:0.49131
# [2300]	validation_0-logloss:0.45392	validation_1-logloss:0.49123
# [2400]	validation_0-logloss:0.45253	validation_1-logloss:0.49119
# [2500]	validation_0-logloss:0.45117	validation_1-logloss:0.49118
# [2600]	validation_0-logloss:0.44985	validation_1-logloss:0.49113
# [2700]	validation_0-logloss:0.44858	validation_1-logloss:0.49107
# [2800]	validation_0-logloss:0.44730	validation_1-logloss:0.49101
# [2900]	validation_0-logloss:0.44600	validation_1-logloss:0.49097
# [2996]	validation_0-logloss:0.44484	validation_1-logloss:0.49097
# (2948),
# #########################
# ### Fold 5
# #########################
# [0]	validation_0-logloss:0.69036	validation_1-logloss:0.69038
# [100]	validation_0-logloss:0.55633	validation_1-logloss:0.55834
# [200]	validation_0-logloss:0.52158	validation_1-logloss:0.52539
# [300]	validation_0-logloss:0.50707	validation_1-logloss:0.51262
# [400]	validation_0-logloss:0.49850	validation_1-logloss:0.50600
# [500]	validation_0-logloss:0.49265	validation_1-logloss:0.50210
# [600]	validation_0-logloss:0.48821	validation_1-logloss:0.49953
# [700]	validation_0-logloss:0.48453	validation_1-logloss:0.49789
# [800]	validation_0-logloss:0.48149	validation_1-logloss:0.49668
# [900]	validation_0-logloss:0.47870	validation_1-logloss:0.49581
# [1000]	validation_0-logloss:0.47625	validation_1-logloss:0.49511
# [1100]	validation_0-logloss:0.47400	validation_1-logloss:0.49467
# [1200]	validation_0-logloss:0.47193	validation_1-logloss:0.49425
# [1300]	validation_0-logloss:0.47003	validation_1-logloss:0.49391
# [1400]	validation_0-logloss:0.46811	validation_1-logloss:0.49358
# [1500]	validation_0-logloss:0.46628	validation_1-logloss:0.49335
# [1600]	validation_0-logloss:0.46460	validation_1-logloss:0.49316
# [1700]	validation_0-logloss:0.46288	validation_1-logloss:0.49303
# [1800]	validation_0-logloss:0.46123	validation_1-logloss:0.49285
# [1900]	validation_0-logloss:0.45971	validation_1-logloss:0.49274
# [2000]	validation_0-logloss:0.45818	validation_1-logloss:0.49261
# [2100]	validation_0-logloss:0.45670	validation_1-logloss:0.49248
# [2200]	validation_0-logloss:0.45525	validation_1-logloss:0.49240
# [2300]	validation_0-logloss:0.45381	validation_1-logloss:0.49227
# [2400]	validation_0-logloss:0.45246	validation_1-logloss:0.49217
# [2500]	validation_0-logloss:0.45112	validation_1-logloss:0.49209
# [2600]	validation_0-logloss:0.44978	validation_1-logloss:0.49201
# [2700]	validation_0-logloss:0.44847	validation_1-logloss:0.49191
# [2800]	validation_0-logloss:0.44715	validation_1-logloss:0.49182
# [2900]	validation_0-logloss:0.44593	validation_1-logloss:0.49180
# [2999]	validation_0-logloss:0.44479	validation_1-logloss:0.49176
# (3000),

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_feature_importance(importance,names,model_type):

    #Create arrays from feature importance and feature names
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    #Create a DataFrame using a Dictionary
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)

    #Sort the DataFrame in order decreasing feature importance
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_df = fi_df.head(50)
    #Define size of bar plot
    plt.figure(figsize=(20,10))
    #Plot Searborn bar chart
    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
    #Add chart labels
    plt.title(model_type + 'FEATURE IMPORTANCE')
    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')
feat_imp = {}
for k, v in models.items():
    for x, y in zip(v.feature_importances_, v.feature_names_in_):
        if y not in feat_imp:
            feat_imp[y] = x
        else:
            feat_imp[y]+=x
plot_feature_importance(list(feat_imp.values()),list(feat_imp.keys()),'')

# %%
scores = []; thresholds = []
best_score = 0; best_threshold = 0

for threshold in np.arange(0.4,0.9,0.01):
    print(f'{threshold:.02f}, ',end='')
    preds = (oof>threshold).astype('int')
    m = f1_score(X['correct'], preds, average='macro')
    scores.append(m)
    thresholds.append(threshold)
    if m>best_score:
        best_score = m
        best_threshold = threshold
# Out:
# 0.40, 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.50, 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.60, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.70, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.80, 0.81, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89,

# %%
import matplotlib.pyplot as plt

# PLOT THRESHOLD VS. F1_SCORE
plt.figure(figsize=(20,5))
plt.plot(thresholds,scores,'-o',color='blue')
plt.scatter([best_threshold], [best_score], color='blue', s=300, alpha=1)
plt.xlabel('Threshold',size=14)
plt.ylabel('Validation F1 Score',size=14)
plt.title(f'Threshold vs. F1_Score with Best F1_Score = {best_score:.5f} at Best Threshold = {best_threshold:.3}',size=18)
plt.show()
